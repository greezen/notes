# %% [markdown]
# ## 小象学院课程
# ## Pyhton数据分析
# ## 爬取PM2.5(细颗粒物)及空气质量指数(AQI)数据
# http://www.pm25.in/
# 提供PM2.5(细颗粒物)及空气质量指数(AQI)实时查询的网站，同时开放PM2.5监测数据查询的API给开发者使用！

# %% [markdown]
# > **提示**：<br>
# 1、这样的文字将会指导你如何使用 jupyter Notebook 来完成项目。<br>
# 2、你可以通过单击代码区域，然后使用键盘快捷键 Shift+Enter 或 Shift+Return 来运行代码。或者在选择代码后使用执行（run cell）按钮执行代码。Markdown的文字区域也同样可以如此操作。<br>
# 3、在如下有# TODO 提示的地方，将代码补全，实现注释中所要求的功能。<br>
# 4、在有"** 回答：**" 提示的地方，回答其上所提出的问题。<br>

# %% [markdown]
# ### 分析流程
# * 爬取url的网页数据：url可以是一级网址，也可以是二级网址
# * 依据二级网址获得城市指数
# * 依据一级网址获得热门城市的城市名称、城市链接（根据城市链接【二级网址】获得城市的指数数据）
# * 写入json文件
# * 主函数

# %% [markdown]
# ### 项目分析
# 对网址http://www.pm25.in/ 进行分析，获得热门城市的名称和链接（二级网址），然后依据二级网址获得该城市的各种指数，以下对各种指数【AQI、PM2.5/1h、PM10/1h、CO/1h、NO2/1h、O3/1h、O3/8h、SO2/1h】进行说明<br>
# * city_name：热门城市名称
# * city_link：城市链接（二级网址）
# * AQI：空气质量指数(AQI)，即air quality index，是定量描述空气质量状况的无纲量指数
# * PM2.5/1h：颗粒物（粒径小于等于2.5μm）1小时平均
# * PM10/1h：颗粒物（粒径小于等于10μm）1小时滑动平均
# * CO/1h：一氧化碳1小时平均
# * NO2/1h：二氧化氮1小时平均
# * O3/1h：臭氧1小时平均
# * O3/8h：臭氧8小时滑动平均
# * SO2/1h：二氧化硫1小时平均<br>
# #### 对指数更详细说明的网址是：http://www.pm25.in/api_doc

# %% [markdown]
# 导入需要的库

# %%
import requests
from bs4 import BeautifulSoup
import json

# %% [markdown]
# 爬取url的源代码，使用"html.parser"对源代码进行解析，该url可以是一级网址，也可以是二级网址

# %%
def get_soup_obj(url):
    url_obj = requests.get(url)
    soup = BeautifulSoup(url_obj.content, 'html.parser')
    return soup

# %% [markdown]
# 依据city_aqi_item['city_link']二级网址获得该城市的各种指数

# %%
def get_secondpage(city_aqi_item):
    """
    功能：
        通过二级网址获得城市的一些指数
    参数：
        city_aqi_item：可以是字典，通过该字典可以获得二级网址，或者直接是二级网址，这个参数主要是为了能把二级网址传入方法中
    返回值：
        通过城市对应的链接（二级网址）获得该城市的各种指数
    """
#     TODO
#     通过城市对应的链接（二级网址）获得该城市的各种指数
    soup = get_soup_obj(city_aqi_item["city_link"])
    data = soup.find("div", class_="span12 data")
    aqi_item = {}
    for item in data.find_all("div", class_="span1"):
        caption = item.find("div", class_="caption")
        if caption:
            aqi_item[caption.text.strip()] = item.find("div", class_="value").text.strip()
    return aqi_item

# %% [markdown]
# 依据'http://www.pm25.in/' 网址获得热门城市下的所有城市名称，以及该城市对应的链接，以及该城市的各种指数【AQI、PM2.5/1h、PM10/1h、CO/1h、NO2/1h、O3/1h、O3/8h、SO2/1h】数据

# %%
def get_fistpage_and_secondpage(url,soup):
    """
    功能：
        通过一级网址获得城市名称和对应的链接（二级网址），然后通过对应的链接（二级网址）得到该城市的一些指数，
        这个方法可以通过传参二级网址调用get_secondpage方法获得城市对应的各种指数
    参数：
        url:一级网址
        soup:需要分析的一级网址的源代码数据
    返回值：
        返回一个列表，列表的元素是字典，字典的元素是城市名称、城市对应的链接、城市的各种指数
    """
#     需要返回的列表
    city_aqi_list = []
    
#     TODO
#     对soup的源代码数据进行分析，获得城市名称，城市链接，然后根据城市链接获得该城市的各种指数
    city_list = soup.find("div", class_="all").find_all("li")
    
    for city in city_list:
        city_aqi_item = {}
        city_aqi_item["name"] = city.find("a").text
        city_aqi_item["city_link"] = url + city.find("a")["href"]
        city_aqi_item["aqi"] = get_secondpage(city_aqi_item)
        city_aqi_list.append(city_aqi_item)

    return city_aqi_list

# %% [markdown]
# 将查询得到的数据下入json数据文件

# %%
def write_city_aqi(city_aqi_data):
    file_path = './dataFile/city_aqi.json'
    
#     TODO
#     将得到的city_aqi_data数据存入json文件
    with open(file_path, "w") as f:
        json.dump(city_aqi_data, f)

# %% [markdown]
# 使用main函数执行以上方法

# %%
if __name__=="__main__":
    
#     需要分析的url
    url = 'http://www.pm25.in/'
    
#     获得url的解析数据
    soup = get_soup_obj(url)
    
#     获得从一级网址和二级网址获得的结果数据综合
    city_aqi_list = get_fistpage_and_secondpage(url,soup)

#     对爬取到的热门城市名称、城市链接、城市的各种指数数据进行遍历
    for city_aqi in city_aqi_list:
        print(city_aqi)

#     将得到的数据写入json文件
    write_city_aqi(city_aqi_list)
# Out:
# {'name': '阿坝州', 'city_link': 'http://www.pm25.in/abazhou', 'aqi': {'AQI': '43', 'PM2.5/1h': '9', 'PM10/1h': '12', 'CO/1h': '1.63', 'NO2/1h': '5', 'O3/1h': '95', 'O3/8h': '85', 'SO2/1h': '8'}}
# {'name': '阿克苏地区', 'city_link': 'http://www.pm25.in/akesudiqu', 'aqi': {'AQI': '94', 'PM2.5/1h': '36', 'PM10/1h': '136', 'CO/1h': '0.4', 'NO2/1h': '10', 'O3/1h': '102', 'O3/8h': '66', 'SO2/1h': '9'}}
# {'name': '阿拉善盟', 'city_link': 'http://www.pm25.in/alashanmeng', 'aqi': {'AQI': '58', 'PM2.5/1h': '9', 'PM10/1h': '22', 'CO/1h': '0.43', 'NO2/1h': '5', 'O3/1h': '123', 'O3/8h': '108', 'SO2/1h': '10'}}
# {'name': '阿勒泰地区', 'city_link': 'http://www.pm25.in/aletaidiqu', 'aqi': {'AQI': '40', 'PM2.5/1h': '16', 'PM10/1h': '39', 'CO/1h': '0.65', 'NO2/1h': '50', 'O3/1h': '31', 'O3/8h': '35', 'SO2/1h': '10'}}
# {'name': '阿里地区', 'city_link': 'http://www.pm25.in/alidiqu', 'aqi': {'AQI': '44', 'PM2.5/1h': '13', 'PM10/1h': '26', 'CO/1h': '0.5', 'NO2/1h': '3', 'O3/1h': '91', 'O3/8h': '86', 'SO2/1h': '4'}}
# {'name': '安康', 'city_link': 'http://www.pm25.in/ankang', 'aqi': {'AQI': '56', 'PM2.5/1h': '19', 'PM10/1h': '59', 'CO/1h': '0.47', 'NO2/1h': '26', 'O3/1h': '90', 'O3/8h': '53', 'SO2/1h': '9'}}
# {'name': '安庆', 'city_link': 'http://www.pm25.in/anqing', 'aqi': {'AQI': '53', 'PM2.5/1h': '23', 'PM10/1h': '53', 'CO/1h': '0.54', 'NO2/1h': '11', 'O3/1h': '124', 'O3/8h': '101', 'SO2/1h': '7'}}
# {'name': '鞍山', 'city_link': 'http://www.pm25.in/anshan', 'aqi': {'AQI': '37', 'PM2.5/1h': '16', 'PM10/1h': '36', 'CO/1h': '0.44', 'NO2/1h': '18', 'O3/1h': '81', 'O3/8h': '67', 'SO2/1h': '9'}}
# {'name': '安顺', 'city_link': 'http://www.pm25.in/anshun', 'aqi': {'AQI': '48', 'PM2.5/1h': '33', 'PM10/1h': '37', 'CO/1h': '0.45', 'NO2/1h': '15', 'O3/1h': '73', 'O3/8h': '73', 'SO2/1h': '12'}}
# {'name': '安阳', 'city_link': 'http://www.pm25.in/anyang', 'aqi': {'AQI': '62', 'PM2.5/1h': '14', 'PM10/1h': '71', 'CO/1h': '0.44', 'NO2/1h': '12', 'O3/1h': '112', 'O3/8h': '97', 'SO2/1h': '10'}}
# {'name': '白城', 'city_link': 'http://www.pm25.in/baicheng', 'aqi': {'AQI': '48', 'PM2.5/1h': '18', 'PM10/1h': '0', 'CO/1h': '0.3', 'NO2/1h': '14', 'O3/1h': '95', 'O3/8h': '94', 'SO2/1h': '12'}}
# {'name': '百色', 'city_link': 'http://www.pm25.in/baise', 'aqi': {'AQI': '47', 'PM2.5/1h': '22', 'PM10/1h': '46', 'CO/1h': '0.85', 'NO2/1h': '20', 'O3/1h': '68', 'O3/8h': '59', 'SO2/1h': '11'}}
# {'name': '白山', 'city_link': 'http://www.pm25.in/baishan', 'aqi': {'AQI': '45', 'PM2.5/1h': '18', 'PM10/1h': '33', 'CO/1h': '0.75', 'NO2/1h': '9', 'O3/1h': '100', 'O3/8h': '89', 'SO2/1h': '8'}}
# {'name': '白银', 'city_link': 'http://www.pm25.in/baiyin', 'aqi': {'AQI': '53', 'PM2.5/1h': '29', 'PM10/1h': '53', 'CO/1h': '0.45', 'NO2/1h': '11', 'O3/1h': '111', 'O3/8h': '100', 'SO2/1h': '11'}}
# {'name': '保定', 'city_link': 'http://www.pm25.in/baoding', 'aqi': {'AQI': '53', 'PM2.5/1h': '14', 'PM10/1h': '53', 'CO/1h': '0.27', 'NO2/1h': '14', 'O3/1h': '95', 'O3/8h': '87', 'SO2/1h': '5'}}
# {'name': '宝鸡', 'city_link': 'http://www.pm25.in/baoji', 'aqi': {'AQI': '61', 'PM2.5/1h': '26', 'PM10/1h': '70', 'CO/1h': '0.61', 'NO2/1h': '21', 'O3/1h': '103', 'O3/8h': '74', 'SO2/1h': '7'}}
# {'name': '保山', 'city_link': 'http://www.pm25.in/baoshan', 'aqi': {'AQI': '60', 'PM2.5/1h': '38', 'PM10/1h': '63', 'CO/1h': '0.6', 'NO2/1h': '7', 'O3/1h': '128', 'O3/8h': '110', 'SO2/1h': '4'}}
# {'name': '包头', 'city_link': 'http://www.pm25.in/baotou', 'aqi': {'AQI': '35', 'PM2.5/1h': '8', 'PM10/1h': '34', 'CO/1h': '0.42', 'NO2/1h': '9', 'O3/1h': '91', 'O3/8h': '69', 'SO2/1h': '6'}}
# {'name': '巴彦淖尔', 'city_link': 'http://www.pm25.in/bayannaoer', 'aqi': {'AQI': '37', 'PM2.5/1h': '8', 'PM10/1h': '15', 'CO/1h': '0.47', 'NO2/1h': '9', 'O3/1h': '85', 'O3/8h': '72', 'SO2/1h': '6'}}
# {'name': '巴中', 'city_link': 'http://www.pm25.in/bazhong', 'aqi': {'AQI': '44', 'PM2.5/1h': '23', 'PM10/1h': '43', 'CO/1h': '0.28', 'NO2/1h': '14', 'O3/1h': '109', 'O3/8h': '75', 'SO2/1h': '5'}}
# {'name': '北海', 'city_link': 'http://www.pm25.in/beihai', 'aqi': {'AQI': '58', 'PM2.5/1h': '40', 'PM10/1h': '55', 'CO/1h': '0.9', 'NO2/1h': '13', 'O3/1h': '64', 'O3/8h': '56', 'SO2/1h': '7'}}
# {'name': '北京', 'city_link': 'http://www.pm25.in/beijing', 'aqi': {'AQI': '47', 'PM2.5/1h': '13', 'PM10/1h': '46', 'CO/1h': '0.24', 'NO2/1h': '17', 'O3/1h': '76', 'O3/8h': '78', 'SO2/1h': '2'}}
# {'name': '蚌埠', 'city_link': 'http://www.pm25.in/bengbu', 'aqi': {'AQI': '58', 'PM2.5/1h': '18', 'PM10/1h': '64', 'CO/1h': '0.43', 'NO2/1h': '13', 'O3/1h': '122', 'O3/8h': '98', 'SO2/1h': '13'}}
# {'name': '本溪', 'city_link': 'http://www.pm25.in/benxi', 'aqi': {'AQI': '52', 'PM2.5/1h': '35', 'PM10/1h': '52', 'CO/1h': '0.88', 'NO2/1h': '32', 'O3/1h': '59', 'O3/8h': '48', 'SO2/1h': '18'}}
# {'name': '毕节', 'city_link': 'http://www.pm25.in/bijie', 'aqi': {'AQI': '35', 'PM2.5/1h': '10', 'PM10/1h': '17', 'CO/1h': '0.45', 'NO2/1h': '19', 'O3/1h': '76', 'O3/8h': '68', 'SO2/1h': '8'}}
# {'name': '滨州', 'city_link': 'http://www.pm25.in/binzhou', 'aqi': {'AQI': '47', 'PM2.5/1h': '6', 'PM10/1h': '31', 'CO/1h': '0.6', 'NO2/1h': '22', 'O3/1h': '98', 'O3/8h': '93', 'SO2/1h': '8'}}
# {'name': '博州', 'city_link': 'http://www.pm25.in/boertala', 'aqi': {'AQI': '48', 'PM2.5/1h': '24', 'PM10/1h': '47', 'CO/1h': '0.45', 'NO2/1h': '23', 'O3/1h': '57', 'O3/8h': '50', 'SO2/1h': '9'}}
# {'name': '亳州', 'city_link': 'http://www.pm25.in/bozhou', 'aqi': {'AQI': '48', 'PM2.5/1h': '26', 'PM10/1h': '26', 'CO/1h': '0.3', 'NO2/1h': '15', 'O3/1h': '113', 'O3/8h': '95', 'SO2/1h': '9'}}
# {'name': '沧州', 'city_link': 'http://www.pm25.in/cangzhou', 'aqi': {'AQI': '44', 'PM2.5/1h': '14', 'PM10/1h': '31', 'CO/1h': '0.33', 'NO2/1h': '12', 'O3/1h': '88', 'O3/8h': '87', 'SO2/1h': '12'}}
# {'name': '长春', 'city_link': 'http://www.pm25.in/changchun', 'aqi': {'AQI': '42', 'PM2.5/1h': '15', 'PM10/1h': '30', 'CO/1h': '0.45', 'NO2/1h': '14', 'O3/1h': '83', 'O3/8h': '83', 'SO2/1h': '4'}}
# {'name': '常德', 'city_link': 'http://www.pm25.in/changde', 'aqi': {'AQI': '48', 'PM2.5/1h': '21', 'PM10/1h': '38', 'CO/1h': '0.68', 'NO2/1h': '24', 'O3/1h': '133', 'O3/8h': '95', 'SO2/1h': '7'}}
# {'name': '昌都', 'city_link': 'http://www.pm25.in/changdou', 'aqi': {'AQI': '28', 'PM2.5/1h': '3', 'PM10/1h': '18', 'CO/1h': '0.7', 'NO2/1h': '11', 'O3/1h': '54', 'O3/8h': '54', 'SO2/1h': '4'}}
# {'name': '昌都地区', 'city_link': 'http://www.pm25.in/changdudiqu', 'aqi': {'AQI': '29', 'PM2.5/1h': '6', 'PM10/1h': '12', 'CO/1h': '0.7', 'NO2/1h': '11', 'O3/1h': '86', 'O3/8h': '57', 'SO2/1h': '8'}}
# {'name': '昌吉州', 'city_link': 'http://www.pm25.in/changjizhou', 'aqi': {'AQI': '103', 'PM2.5/1h': '76', 'PM10/1h': '96', 'CO/1h': '1.1', 'NO2/1h': '25', 'O3/1h': '56', 'O3/8h': '47', 'SO2/1h': '5'}}
# {'name': '长沙', 'city_link': 'http://www.pm25.in/changsha', 'aqi': {'AQI': '61', 'PM2.5/1h': '43', 'PM10/1h': '63', 'CO/1h': '0.71', 'NO2/1h': '34', 'O3/1h': '104', 'O3/8h': '81', 'SO2/1h': '7'}}
# {'name': '常熟', 'city_link': 'http://www.pm25.in/changshu', 'aqi': {'AQI': '53', 'PM2.5/1h': '19', 'PM10/1h': '53', 'CO/1h': '0.5', 'NO2/1h': '33', 'O3/1h': '98', 'O3/8h': '88', 'SO2/1h': '16'}}
# {'name': '长治', 'city_link': 'http://www.pm25.in/changzhi', 'aqi': {'AQI': '49', 'PM2.5/1h': '7', 'PM10/1h': '36', 'CO/1h': '0.62', 'NO2/1h': '12', 'O3/1h': '104', 'O3/8h': '97', 'SO2/1h': '8'}}
# {'name': '常州', 'city_link': 'http://www.pm25.in/changzhou', 'aqi': {'AQI': '41', 'PM2.5/1h': '22', 'PM10/1h': '40', 'CO/1h': '0.7', 'NO2/1h': '33', 'O3/1h': '76', 'O3/8h': '68', 'SO2/1h': '11'}}
# {'name': '朝阳', 'city_link': 'http://www.pm25.in/chaoyang', 'aqi': {'AQI': '44', 'PM2.5/1h': '9', 'PM10/1h': '30', 'CO/1h': '0.57', 'NO2/1h': '6', 'O3/1h': '84', 'O3/8h': '86', 'SO2/1h': '5'}}
# {'name': '潮州', 'city_link': 'http://www.pm25.in/chaozhou', 'aqi': {'AQI': '64', 'PM2.5/1h': '43', 'PM10/1h': '75', 'CO/1h': '0.97', 'NO2/1h': '17', 'O3/1h': '69', 'O3/8h': '58', 'SO2/1h': '11'}}
# {'name': '承德', 'city_link': 'http://www.pm25.in/chengde', 'aqi': {'AQI': '43', 'PM2.5/1h': '7', 'PM10/1h': '16', 'CO/1h': '0.42', 'NO2/1h': '8', 'O3/1h': '87', 'O3/8h': '85', 'SO2/1h': '8'}}
# {'name': '成都', 'city_link': 'http://www.pm25.in/chengdu', 'aqi': {'AQI': '55', 'PM2.5/1h': '31', 'PM10/1h': '57', 'CO/1h': '0.6', 'NO2/1h': '35', 'O3/1h': '65', 'O3/8h': '51', 'SO2/1h': '7'}}
# {'name': '郴州', 'city_link': 'http://www.pm25.in/chenzhou', 'aqi': {'AQI': '72', 'PM2.5/1h': '52', 'PM10/1h': '82', 'CO/1h': '1.0', 'NO2/1h': '30', 'O3/1h': '47', 'O3/8h': '53', 'SO2/1h': '9'}}
# {'name': '赤峰', 'city_link': 'http://www.pm25.in/chifeng', 'aqi': {'AQI': '38', 'PM2.5/1h': '3', 'PM10/1h': '15', 'CO/1h': '0.3', 'NO2/1h': '14', 'O3/1h': '71', 'O3/8h': '74', 'SO2/1h': '8'}}
# {'name': '池州', 'city_link': 'http://www.pm25.in/chizhou', 'aqi': {'AQI': '63', 'PM2.5/1h': '28', 'PM10/1h': '43', 'CO/1h': '0.53', 'NO2/1h': '21', 'O3/1h': '126', 'O3/8h': '114', 'SO2/1h': '9'}}
# {'name': '重庆', 'city_link': 'http://www.pm25.in/chongqing', 'aqi': {'AQI': '47', 'PM2.5/1h': '32', 'PM10/1h': '46', 'CO/1h': '0.65', 'NO2/1h': '31', 'O3/1h': '61', 'O3/8h': '44', 'SO2/1h': '6'}}
# {'name': '崇左', 'city_link': 'http://www.pm25.in/chongzuo', 'aqi': {'AQI': '63', 'PM2.5/1h': '24', 'PM10/1h': '74', 'CO/1h': '0.7', 'NO2/1h': '21', 'O3/1h': '68', 'O3/8h': '65', 'SO2/1h': '3'}}
# {'name': '楚雄州', 'city_link': 'http://www.pm25.in/chuxiongzhou', 'aqi': {'AQI': '59', 'PM2.5/1h': '41', 'PM10/1h': '54', 'CO/1h': '0.8', 'NO2/1h': '8', 'O3/1h': '122', 'O3/8h': '95', 'SO2/1h': '9'}}
# {'name': '滁州', 'city_link': 'http://www.pm25.in/chuzhou', 'aqi': {'AQI': '61', 'PM2.5/1h': '31', 'PM10/1h': '70', 'CO/1h': '0.43', 'NO2/1h': '13', 'O3/1h': '109', 'O3/8h': '86', 'SO2/1h': '10'}}
# {'name': '大连', 'city_link': 'http://www.pm25.in/dalian', 'aqi': {'AQI': '50', 'PM2.5/1h': '18', 'PM10/1h': '49', 'CO/1h': '0.32', 'NO2/1h': '16', 'O3/1h': '84', 'O3/8h': '81', 'SO2/1h': '7'}}
# {'name': '大理州', 'city_link': 'http://www.pm25.in/dalizhou', 'aqi': {'AQI': '59', 'PM2.5/1h': '20', 'PM10/1h': '48', 'CO/1h': '0.65', 'NO2/1h': '9', 'O3/1h': '116', 'O3/8h': '109', 'SO2/1h': '4'}}
# {'name': '丹东', 'city_link': 'http://www.pm25.in/dandong', 'aqi': {'AQI': '49', 'PM2.5/1h': '28', 'PM10/1h': '48', 'CO/1h': '0.63', 'NO2/1h': '19', 'O3/1h': '74', 'O3/8h': '59', 'SO2/1h': '12'}}
# {'name': '大庆', 'city_link': 'http://www.pm25.in/daqing', 'aqi': {'AQI': '40', 'PM2.5/1h': '9', 'PM10/1h': '15', 'CO/1h': '0.32', 'NO2/1h': '13', 'O3/1h': '86', 'O3/8h': '79', 'SO2/1h': '8'}}
# {'name': '大同', 'city_link': 'http://www.pm25.in/datong', 'aqi': {'AQI': '39', 'PM2.5/1h': '5', 'PM10/1h': '29', 'CO/1h': '0.44', 'NO2/1h': '9', 'O3/1h': '89', 'O3/8h': '77', 'SO2/1h': '8'}}
# {'name': '大兴安岭地', 'city_link': 'http://www.pm25.in/daxinganlingde', 'aqi': {'AQI': '0', 'PM2.5/1h': '0', 'PM10/1h': '0', 'CO/1h': '0.0', 'NO2/1h': '0', 'O3/1h': '0', 'O3/8h': '0', 'SO2/1h': '0'}}
# {'name': '大兴安岭地区', 'city_link': 'http://www.pm25.in/daxinganlingdiqu', 'aqi': {'AQI': '46', 'PM2.5/1h': '10', 'PM10/1h': '9', 'CO/1h': '0.4', 'NO2/1h': '9', 'O3/1h': '92', 'O3/8h': '90', 'SO2/1h': '12'}}
# {'name': '达州', 'city_link': 'http://www.pm25.in/dazhou', 'aqi': {'AQI': '70', 'PM2.5/1h': '50', 'PM10/1h': '74', 'CO/1h': '0.74', 'NO2/1h': '24', 'O3/1h': '108', 'O3/8h': '77', 'SO2/1h': '9'}}
# {'name': '德宏州', 'city_link': 'http://www.pm25.in/dehongzhou', 'aqi': {'AQI': '70', 'PM2.5/1h': '43', 'PM10/1h': '88', 'CO/1h': '0.85', 'NO2/1h': '11', 'O3/1h': '124', 'O3/8h': '93', 'SO2/1h': '6'}}
# {'name': '德阳', 'city_link': 'http://www.pm25.in/deyang', 'aqi': {'AQI': '60', 'PM2.5/1h': '36', 'PM10/1h': '67', 'CO/1h': '0.48', 'NO2/1h': '34', 'O3/1h': '74', 'O3/8h': '60', 'SO2/1h': '10'}}
# {'name': '德州', 'city_link': 'http://www.pm25.in/dezhou', 'aqi': {'AQI': '55', 'PM2.5/1h': '7', 'PM10/1h': '57', 'CO/1h': '0.5', 'NO2/1h': '17', 'O3/1h': '99', 'O3/8h': '92', 'SO2/1h': '5'}}
# {'name': '定西', 'city_link': 'http://www.pm25.in/dingxi', 'aqi': {'AQI': '54', 'PM2.5/1h': '12', 'PM10/1h': '56', 'CO/1h': '0.4', 'NO2/1h': '13', 'O3/1h': '101', 'O3/8h': '80', 'SO2/1h': '5'}}
# {'name': '迪庆州', 'city_link': 'http://www.pm25.in/diqingzhou', 'aqi': {'AQI': '54', 'PM2.5/1h': '22', 'PM10/1h': '43', 'CO/1h': '0.45', 'NO2/1h': '5', 'O3/1h': '112', 'O3/8h': '103', 'SO2/1h': '5'}}
# {'name': '东莞', 'city_link': 'http://www.pm25.in/dongguan', 'aqi': {'AQI': '49', 'PM2.5/1h': '34', 'PM10/1h': '40', 'CO/1h': '0.7', 'NO2/1h': '39', 'O3/1h': '68', 'O3/8h': '66', 'SO2/1h': '6'}}
# {'name': '东营', 'city_link': 'http://www.pm25.in/dongying', 'aqi': {'AQI': '46', 'PM2.5/1h': '8', 'PM10/1h': '35', 'CO/1h': '0.3', 'NO2/1h': '15', 'O3/1h': '87', 'O3/8h': '91', 'SO2/1h': '10'}}
# {'name': '鄂尔多斯', 'city_link': 'http://www.pm25.in/eerduosi', 'aqi': {'AQI': '43', 'PM2.5/1h': '4', 'PM10/1h': '13', 'CO/1h': '0.44', 'NO2/1h': '10', 'O3/1h': '93', 'O3/8h': '85', 'SO2/1h': '5'}}
# {'name': '恩施州', 'city_link': 'http://www.pm25.in/enshizhou', 'aqi': {'AQI': '34', 'PM2.5/1h': '15', 'PM10/1h': '28', 'CO/1h': '0.7', 'NO2/1h': '9', 'O3/1h': '87', 'O3/8h': '67', 'SO2/1h': '3'}}
# {'name': '鄂州', 'city_link': 'http://www.pm25.in/ezhou', 'aqi': {'AQI': '59', 'PM2.5/1h': '24', 'PM10/1h': '66', 'CO/1h': '0.47', 'NO2/1h': '24', 'O3/1h': '112', 'O3/8h': '93', 'SO2/1h': '8'}}
# {'name': '防城港', 'city_link': 'http://www.pm25.in/fangchenggang', 'aqi': {'AQI': '49', 'PM2.5/1h': '34', 'PM10/1h': '46', 'CO/1h': '0.87', 'NO2/1h': '23', 'O3/1h': '46', 'O3/8h': '51', 'SO2/1h': '4'}}
# {'name': '佛山', 'city_link': 'http://www.pm25.in/foshan', 'aqi': {'AQI': '45', 'PM2.5/1h': '26', 'PM10/1h': '44', 'CO/1h': '0.69', 'NO2/1h': '33', 'O3/1h': '77', 'O3/8h': '68', 'SO2/1h': '6'}}
# {'name': '抚顺', 'city_link': 'http://www.pm25.in/fushun', 'aqi': {'AQI': '44', 'PM2.5/1h': '21', 'PM10/1h': '43', 'CO/1h': '0.4', 'NO2/1h': '11', 'O3/1h': '94', 'O3/8h': '73', 'SO2/1h': '9'}}
# {'name': '阜新', 'city_link': 'http://www.pm25.in/fuxin', 'aqi': {'AQI': '43', 'PM2.5/1h': '5', 'PM10/1h': '18', 'CO/1h': '0.26', 'NO2/1h': '6', 'O3/1h': '87', 'O3/8h': '85', 'SO2/1h': '5'}}
# {'name': '阜阳', 'city_link': 'http://www.pm25.in/fuyang', 'aqi': {'AQI': '73', 'PM2.5/1h': '39', 'PM10/1h': '94', 'CO/1h': '0.4', 'NO2/1h': '19', 'O3/1h': '136', 'O3/8h': '99', 'SO2/1h': '7'}}
# {'name': '富阳', 'city_link': 'http://www.pm25.in/fuyangshi', 'aqi': {'AQI': '30', 'PM2.5/1h': '16', 'PM10/1h': '29', 'CO/1h': '0.6', 'NO2/1h': '8', 'O3/1h': '49', 'O3/8h': '41', 'SO2/1h': '2'}}
# {'name': '福州', 'city_link': 'http://www.pm25.in/fuzhou', 'aqi': {'AQI': '48', 'PM2.5/1h': '13', 'PM10/1h': '47', 'CO/1h': '0.48', 'NO2/1h': '29', 'O3/1h': '86', 'O3/8h': '67', 'SO2/1h': '4'}}
# {'name': '抚州', 'city_link': 'http://www.pm25.in/fuzhoushi', 'aqi': {'AQI': '52', 'PM2.5/1h': '29', 'PM10/1h': '52', 'CO/1h': '0.66', 'NO2/1h': '7', 'O3/1h': '120', 'O3/8h': '89', 'SO2/1h': '6'}}
# {'name': '甘南州', 'city_link': 'http://www.pm25.in/gannanzhou', 'aqi': {'AQI': '47', 'PM2.5/1h': '9', 'PM10/1h': '24', 'CO/1h': '0.0', 'NO2/1h': '12', 'O3/1h': '99', 'O3/8h': '93', 'SO2/1h': '3'}}
# {'name': '赣州', 'city_link': 'http://www.pm25.in/ganzhou', 'aqi': {'AQI': '52', 'PM2.5/1h': '21', 'PM10/1h': '40', 'CO/1h': '0.94', 'NO2/1h': '20', 'O3/1h': '104', 'O3/8h': '101', 'SO2/1h': '7'}}
# {'name': '甘孜藏族自治州', 'city_link': 'http://www.pm25.in/ganzicangzuzizhizhou', 'aqi': {'AQI': '51', 'PM2.5/1h': '19', 'PM10/1h': '50', 'CO/1h': '0.4', 'NO2/1h': '9', 'O3/1h': '47', 'O3/8h': '41', 'SO2/1h': '5'}}
# {'name': '甘孜州', 'city_link': 'http://www.pm25.in/ganzizhou', 'aqi': {'AQI': '30', 'PM2.5/1h': '0', 'PM10/1h': '0', 'CO/1h': '0.0', 'NO2/1h': '14', 'O3/1h': '69', 'O3/8h': '59', 'SO2/1h': '21'}}
# {'name': '广安', 'city_link': 'http://www.pm25.in/guangan', 'aqi': {'AQI': '39', 'PM2.5/1h': '23', 'PM10/1h': '38', 'CO/1h': '0.6', 'NO2/1h': '19', 'O3/1h': '79', 'O3/8h': '60', 'SO2/1h': '6'}}
# {'name': '广元', 'city_link': 'http://www.pm25.in/guangyuan', 'aqi': {'AQI': '43', 'PM2.5/1h': '22', 'PM10/1h': '42', 'CO/1h': '0.4', 'NO2/1h': '18', 'O3/1h': '87', 'O3/8h': '50', 'SO2/1h': '13'}}
# {'name': '广州', 'city_link': 'http://www.pm25.in/guangzhou', 'aqi': {'AQI': '38', 'PM2.5/1h': '26', 'PM10/1h': '37', 'CO/1h': '0.62', 'NO2/1h': '35', 'O3/1h': '73', 'O3/8h': '72', 'SO2/1h': '4'}}
# {'name': '贵港', 'city_link': 'http://www.pm25.in/guigang', 'aqi': {'AQI': '55', 'PM2.5/1h': '38', 'PM10/1h': '57', 'CO/1h': '0.65', 'NO2/1h': '16', 'O3/1h': '63', 'O3/8h': '57', 'SO2/1h': '7'}}
# {'name': '桂林', 'city_link': 'http://www.pm25.in/guilin', 'aqi': {'AQI': '46', 'PM2.5/1h': '32', 'PM10/1h': '40', 'CO/1h': '0.77', 'NO2/1h': '21', 'O3/1h': '84', 'O3/8h': '79', 'SO2/1h': '9'}}
# {'name': '贵阳', 'city_link': 'http://www.pm25.in/guiyang', 'aqi': {'AQI': '41', 'PM2.5/1h': '21', 'PM10/1h': '40', 'CO/1h': '0.4', 'NO2/1h': '15', 'O3/1h': '87', 'O3/8h': '79', 'SO2/1h': '10'}}
# {'name': '果洛州', 'city_link': 'http://www.pm25.in/guoluozhou', 'aqi': {'AQI': '44', 'PM2.5/1h': '10', 'PM10/1h': '24', 'CO/1h': '1.1', 'NO2/1h': '3', 'O3/1h': '132', 'O3/8h': '86', 'SO2/1h': '8'}}
# {'name': '固原', 'city_link': 'http://www.pm25.in/guyuan', 'aqi': {'AQI': '60', 'PM2.5/1h': '13', 'PM10/1h': '68', 'CO/1h': '0.47', 'NO2/1h': '17', 'O3/1h': '114', 'O3/8h': '99', 'SO2/1h': '8'}}
# {'name': '哈尔滨', 'city_link': 'http://www.pm25.in/haerbin', 'aqi': {'AQI': '39', 'PM2.5/1h': '13', 'PM10/1h': '22', 'CO/1h': '0.44', 'NO2/1h': '18', 'O3/1h': '75', 'O3/8h': '76', 'SO2/1h': '14'}}
# {'name': '海北州', 'city_link': 'http://www.pm25.in/haibeizhou', 'aqi': {'AQI': '67', 'PM2.5/1h': '19', 'PM10/1h': '36', 'CO/1h': '0.4', 'NO2/1h': '12', 'O3/1h': '130', 'O3/8h': '119', 'SO2/1h': '16'}}
# {'name': '海东地区', 'city_link': 'http://www.pm25.in/haidongdiqu', 'aqi': {'AQI': '50', 'PM2.5/1h': '26', 'PM10/1h': '49', 'CO/1h': '0.5', 'NO2/1h': '11', 'O3/1h': '73', 'O3/8h': '58', 'SO2/1h': '8'}}
# {'name': '海口', 'city_link': 'http://www.pm25.in/haikou', 'aqi': {'AQI': '49', 'PM2.5/1h': '27', 'PM10/1h': '48', 'CO/1h': '0.74', 'NO2/1h': '10', 'O3/1h': '77', 'O3/8h': '53', 'SO2/1h': '5'}}
# {'name': '海门', 'city_link': 'http://www.pm25.in/haimen', 'aqi': {'AQI': '70', 'PM2.5/1h': '21', 'PM10/1h': '88', 'CO/1h': '0.45', 'NO2/1h': '15', 'O3/1h': '81', 'O3/8h': '74', 'SO2/1h': '9'}}
# {'name': '海南州', 'city_link': 'http://www.pm25.in/hainanzhou', 'aqi': {'AQI': '65', 'PM2.5/1h': '23', 'PM10/1h': '42', 'CO/1h': '0.5', 'NO2/1h': '5', 'O3/1h': '123', 'O3/8h': '116', 'SO2/1h': '11'}}
# {'name': '海西州', 'city_link': 'http://www.pm25.in/haixizhou', 'aqi': {'AQI': '53', 'PM2.5/1h': '10', 'PM10/1h': '54', 'CO/1h': '0.2', 'NO2/1h': '18', 'O3/1h': '106', 'O3/8h': '100', 'SO2/1h': '5'}}
# {'name': '哈密地区', 'city_link': 'http://www.pm25.in/hamidiqu', 'aqi': {'AQI': '39', 'PM2.5/1h': '10', 'PM10/1h': '34', 'CO/1h': '1.05', 'NO2/1h': '7', 'O3/1h': '96', 'O3/8h': '76', 'SO2/1h': '4'}}
# {'name': '邯郸', 'city_link': 'http://www.pm25.in/handan', 'aqi': {'AQI': '54', 'PM2.5/1h': '8', 'PM10/1h': '55', 'CO/1h': '0.43', 'NO2/1h': '10', 'O3/1h': '118', 'O3/8h': '101', 'SO2/1h': '9'}}
# {'name': '杭州', 'city_link': 'http://www.pm25.in/hangzhou', 'aqi': {'AQI': '57', 'PM2.5/1h': '32', 'PM10/1h': '62', 'CO/1h': '0.61', 'NO2/1h': '22', 'O3/1h': '120', 'O3/8h': '84', 'SO2/1h': '10'}}
# {'name': '汉中', 'city_link': 'http://www.pm25.in/hanzhong', 'aqi': {'AQI': '46', 'PM2.5/1h': '26', 'PM10/1h': '45', 'CO/1h': '0.83', 'NO2/1h': '21', 'O3/1h': '78', 'O3/8h': '52', 'SO2/1h': '6'}}
# {'name': '鹤壁', 'city_link': 'http://www.pm25.in/hebi', 'aqi': {'AQI': '53', 'PM2.5/1h': '11', 'PM10/1h': '54', 'CO/1h': '0.3', 'NO2/1h': '15', 'O3/1h': '99', 'O3/8h': '91', 'SO2/1h': '9'}}
# {'name': '河池', 'city_link': 'http://www.pm25.in/hechi', 'aqi': {'AQI': '45', 'PM2.5/1h': '17', 'PM10/1h': '32', 'CO/1h': '0.67', 'NO2/1h': '11', 'O3/1h': '88', 'O3/8h': '89', 'SO2/1h': '7'}}
# {'name': '合肥', 'city_link': 'http://www.pm25.in/hefei', 'aqi': {'AQI': '57', 'PM2.5/1h': '16', 'PM10/1h': '62', 'CO/1h': '0.37', 'NO2/1h': '18', 'O3/1h': '118', 'O3/8h': '97', 'SO2/1h': '6'}}
# {'name': '鹤岗', 'city_link': 'http://www.pm25.in/hegang', 'aqi': {'AQI': '47', 'PM2.5/1h': '14', 'PM10/1h': '46', 'CO/1h': '0.35', 'NO2/1h': '4', 'O3/1h': '86', 'O3/8h': '85', 'SO2/1h': '17'}}
# {'name': '黑河', 'city_link': 'http://www.pm25.in/heihe', 'aqi': {'AQI': '48', 'PM2.5/1h': '8', 'PM10/1h': '25', 'CO/1h': '0.43', 'NO2/1h': '14', 'O3/1h': '87', 'O3/8h': '94', 'SO2/1h': '14'}}
# {'name': '衡水', 'city_link': 'http://www.pm25.in/hengshui', 'aqi': {'AQI': '54', 'PM2.5/1h': '15', 'PM10/1h': '56', 'CO/1h': '0.33', 'NO2/1h': '14', 'O3/1h': '94', 'O3/8h': '82', 'SO2/1h': '6'}}
# {'name': '衡阳', 'city_link': 'http://www.pm25.in/hengyang', 'aqi': {'AQI': '63', 'PM2.5/1h': '42', 'PM10/1h': '73', 'CO/1h': '0.95', 'NO2/1h': '48', 'O3/1h': '64', 'O3/8h': '62', 'SO2/1h': '12'}}
# {'name': '和田地区', 'city_link': 'http://www.pm25.in/hetiandiqu', 'aqi': {'AQI': '97', 'PM2.5/1h': '36', 'PM10/1h': '142', 'CO/1h': '0.4', 'NO2/1h': '13', 'O3/1h': '74', 'O3/8h': '53', 'SO2/1h': '15'}}
# {'name': '河源', 'city_link': 'http://www.pm25.in/heyuan', 'aqi': {'AQI': '42', 'PM2.5/1h': '22', 'PM10/1h': '41', 'CO/1h': '0.93', 'NO2/1h': '15', 'O3/1h': '82', 'O3/8h': '82', 'SO2/1h': '6'}}
# {'name': '菏泽', 'city_link': 'http://www.pm25.in/heze', 'aqi': {'AQI': '50', 'PM2.5/1h': '7', 'PM10/1h': '41', 'CO/1h': '0.37', 'NO2/1h': '12', 'O3/1h': '113', 'O3/8h': '99', 'SO2/1h': '7'}}
# {'name': '贺州', 'city_link': 'http://www.pm25.in/hezhou', 'aqi': {'AQI': '55', 'PM2.5/1h': '38', 'PM10/1h': '52', 'CO/1h': '0.7', 'NO2/1h': '17', 'O3/1h': '64', 'O3/8h': '65', 'SO2/1h': '11'}}
# {'name': '红河州', 'city_link': 'http://www.pm25.in/honghezhou', 'aqi': {'AQI': '104', 'PM2.5/1h': '77', 'PM10/1h': '92', 'CO/1h': '0.95', 'NO2/1h': '10', 'O3/1h': '124', 'O3/8h': '103', 'SO2/1h': '9'}}
# {'name': '淮安', 'city_link': 'http://www.pm25.in/huaian', 'aqi': {'AQI': '59', 'PM2.5/1h': '25', 'PM10/1h': '66', 'CO/1h': '0.3', 'NO2/1h': '20', 'O3/1h': '106', 'O3/8h': '97', 'SO2/1h': '9'}}
# {'name': '淮北', 'city_link': 'http://www.pm25.in/huaibei', 'aqi': {'AQI': '47', 'PM2.5/1h': '25', 'PM10/1h': '45', 'CO/1h': '0.37', 'NO2/1h': '13', 'O3/1h': '108', 'O3/8h': '92', 'SO2/1h': '10'}}
# {'name': '怀化', 'city_link': 'http://www.pm25.in/huaihua', 'aqi': {'AQI': '63', 'PM2.5/1h': '44', 'PM10/1h': '63', 'CO/1h': '0.78', 'NO2/1h': '21', 'O3/1h': '46', 'O3/8h': '38', 'SO2/1h': '8'}}
# {'name': '淮南', 'city_link': 'http://www.pm25.in/huainan', 'aqi': {'AQI': '63', 'PM2.5/1h': '25', 'PM10/1h': '74', 'CO/1h': '0.37', 'NO2/1h': '14', 'O3/1h': '119', 'O3/8h': '98', 'SO2/1h': '9'}}
# {'name': '黄冈', 'city_link': 'http://www.pm25.in/huanggang', 'aqi': {'AQI': '54', 'PM2.5/1h': '30', 'PM10/1h': '56', 'CO/1h': '0.55', 'NO2/1h': '13', 'O3/1h': '119', 'O3/8h': '102', 'SO2/1h': '5'}}
# {'name': '黄南州', 'city_link': 'http://www.pm25.in/huangnanzhou', 'aqi': {'AQI': '57', 'PM2.5/1h': '25', 'PM10/1h': '62', 'CO/1h': '0.3', 'NO2/1h': '20', 'O3/1h': '0', 'O3/8h': '94', 'SO2/1h': '11'}}
# {'name': '黄山', 'city_link': 'http://www.pm25.in/huangshan', 'aqi': {'AQI': '54', 'PM2.5/1h': '28', 'PM10/1h': '56', 'CO/1h': '0.43', 'NO2/1h': '13', 'O3/1h': '119', 'O3/8h': '89', 'SO2/1h': '6'}}
# {'name': '黄石', 'city_link': 'http://www.pm25.in/huangshi', 'aqi': {'AQI': '62', 'PM2.5/1h': '33', 'PM10/1h': '72', 'CO/1h': '0.7', 'NO2/1h': '28', 'O3/1h': '115', 'O3/8h': '99', 'SO2/1h': '11'}}
# {'name': '呼和浩特', 'city_link': 'http://www.pm25.in/huhehaote', 'aqi': {'AQI': '60', 'PM2.5/1h': '12', 'PM10/1h': '68', 'CO/1h': '0.53', 'NO2/1h': '12', 'O3/1h': '85', 'O3/8h': '73', 'SO2/1h': '11'}}
# {'name': '惠州', 'city_link': 'http://www.pm25.in/huizhou', 'aqi': {'AQI': '46', 'PM2.5/1h': '29', 'PM10/1h': '45', 'CO/1h': '0.6', 'NO2/1h': '20', 'O3/1h': '73', 'O3/8h': '72', 'SO2/1h': '5'}}
# {'name': '葫芦岛', 'city_link': 'http://www.pm25.in/huludao', 'aqi': {'AQI': '38', 'PM2.5/1h': '11', 'PM10/1h': '33', 'CO/1h': '0.4', 'NO2/1h': '13', 'O3/1h': '73', 'O3/8h': '74', 'SO2/1h': '11'}}
# {'name': '呼伦贝尔', 'city_link': 'http://www.pm25.in/hulunbeier', 'aqi': {'AQI': '41', 'PM2.5/1h': '8', 'PM10/1h': '22', 'CO/1h': '0.25', 'NO2/1h': '6', 'O3/1h': '83', 'O3/8h': '81', 'SO2/1h': '2'}}
# {'name': '湖州', 'city_link': 'http://www.pm25.in/huzhou', 'aqi': {'AQI': '77', 'PM2.5/1h': '56', 'PM10/1h': '81', 'CO/1h': '0.81', 'NO2/1h': '50', 'O3/1h': '97', 'O3/8h': '82', 'SO2/1h': '16'}}
# {'name': '佳木斯', 'city_link': 'http://www.pm25.in/jiamusi', 'aqi': {'AQI': '39', 'PM2.5/1h': '14', 'PM10/1h': '18', 'CO/1h': '0.3', 'NO2/1h': '10', 'O3/1h': '77', 'O3/8h': '76', 'SO2/1h': '7'}}
# {'name': '吉安', 'city_link': 'http://www.pm25.in/jian', 'aqi': {'AQI': '60', 'PM2.5/1h': '31', 'PM10/1h': '62', 'CO/1h': '0.65', 'NO2/1h': '22', 'O3/1h': '124', 'O3/8h': '110', 'SO2/1h': '12'}}
# {'name': '江门', 'city_link': 'http://www.pm25.in/jiangmen', 'aqi': {'AQI': '46', 'PM2.5/1h': '27', 'PM10/1h': '45', 'CO/1h': '0.7', 'NO2/1h': '39', 'O3/1h': '81', 'O3/8h': '66', 'SO2/1h': '5'}}
# {'name': '江阴', 'city_link': 'http://www.pm25.in/jiangyin', 'aqi': {'AQI': '66', 'PM2.5/1h': '20', 'PM10/1h': '79', 'CO/1h': '0.37', 'NO2/1h': '21', 'O3/1h': '128', 'O3/8h': '99', 'SO2/1h': '8'}}
# {'name': '胶南', 'city_link': 'http://www.pm25.in/jiaonan', 'aqi': {'AQI': '72', 'PM2.5/1h': '16', 'PM10/1h': '91', 'CO/1h': '0.5', 'NO2/1h': '19', 'O3/1h': '86', 'O3/8h': '81', 'SO2/1h': '7'}}
# {'name': '胶州', 'city_link': 'http://www.pm25.in/jiaozhou', 'aqi': {'AQI': '54', 'PM2.5/1h': '6', 'PM10/1h': '56', 'CO/1h': '0.5', 'NO2/1h': '10', 'O3/1h': '99', 'O3/8h': '95', 'SO2/1h': '5'}}
# {'name': '焦作', 'city_link': 'http://www.pm25.in/jiaozuo', 'aqi': {'AQI': '58', 'PM2.5/1h': '24', 'PM10/1h': '63', 'CO/1h': '0.42', 'NO2/1h': '13', 'O3/1h': '117', 'O3/8h': '107', 'SO2/1h': '7'}}
# {'name': '嘉兴', 'city_link': 'http://www.pm25.in/jiaxing', 'aqi': {'AQI': '72', 'PM2.5/1h': '49', 'PM10/1h': '92', 'CO/1h': '0.77', 'NO2/1h': '26', 'O3/1h': '130', 'O3/8h': '102', 'SO2/1h': '12'}}
# {'name': '嘉峪关', 'city_link': 'http://www.pm25.in/jiayuguan', 'aqi': {'AQI': '53', 'PM2.5/1h': '16', 'PM10/1h': '54', 'CO/1h': '0.4', 'NO2/1h': '10', 'O3/1h': '115', 'O3/8h': '89', 'SO2/1h': '5'}}
# {'name': '揭阳', 'city_link': 'http://www.pm25.in/jieyang', 'aqi': {'AQI': '66', 'PM2.5/1h': '47', 'PM10/1h': '61', 'CO/1h': '1.0', 'NO2/1h': '32', 'O3/1h': '68', 'O3/8h': '57', 'SO2/1h': '9'}}
# {'name': '吉林', 'city_link': 'http://www.pm25.in/jilin', 'aqi': {'AQI': '45', 'PM2.5/1h': '16', 'PM10/1h': '33', 'CO/1h': '0.67', 'NO2/1h': '12', 'O3/1h': '89', 'O3/8h': '88', 'SO2/1h': '6'}}
# {'name': '即墨', 'city_link': 'http://www.pm25.in/jimo', 'aqi': {'AQI': '49', 'PM2.5/1h': '9', 'PM10/1h': '25', 'CO/1h': '0.45', 'NO2/1h': '11', 'O3/1h': '98', 'O3/8h': '97', 'SO2/1h': '5'}}
# {'name': '济南', 'city_link': 'http://www.pm25.in/jinan', 'aqi': {'AQI': '57', 'PM2.5/1h': '12', 'PM10/1h': '62', 'CO/1h': '0.36', 'NO2/1h': '25', 'O3/1h': '91', 'O3/8h': '84', 'SO2/1h': '7'}}
# {'name': '金昌', 'city_link': 'http://www.pm25.in/jinchang', 'aqi': {'AQI': '51', 'PM2.5/1h': '12', 'PM10/1h': '50', 'CO/1h': '0.5', 'NO2/1h': '6', 'O3/1h': '126', 'O3/8h': '98', 'SO2/1h': '4'}}
# {'name': '晋城', 'city_link': 'http://www.pm25.in/jincheng', 'aqi': {'AQI': '51', 'PM2.5/1h': '4', 'PM10/1h': '34', 'CO/1h': '0.4', 'NO2/1h': '13', 'O3/1h': '111', 'O3/8h': '100', 'SO2/1h': '6'}}
# {'name': '景德镇', 'city_link': 'http://www.pm25.in/jingdezhen', 'aqi': {'AQI': '52', 'PM2.5/1h': '24', 'PM10/1h': '52', 'CO/1h': '0.3', 'NO2/1h': '9', 'O3/1h': '109', 'O3/8h': '74', 'SO2/1h': '6'}}
# {'name': '荆门', 'city_link': 'http://www.pm25.in/jingmen', 'aqi': {'AQI': '61', 'PM2.5/1h': '31', 'PM10/1h': '70', 'CO/1h': '0.6', 'NO2/1h': '20', 'O3/1h': '108', 'O3/8h': '85', 'SO2/1h': '8'}}
# {'name': '荆州', 'city_link': 'http://www.pm25.in/jingzhou', 'aqi': {'AQI': '52', 'PM2.5/1h': '28', 'PM10/1h': '52', 'CO/1h': '0.47', 'NO2/1h': '15', 'O3/1h': '127', 'O3/8h': '87', 'SO2/1h': '10'}}
# {'name': '金华', 'city_link': 'http://www.pm25.in/jinhua', 'aqi': {'AQI': '59', 'PM2.5/1h': '30', 'PM10/1h': '66', 'CO/1h': '0.6', 'NO2/1h': '32', 'O3/1h': '104', 'O3/8h': '74', 'SO2/1h': '13'}}
# {'name': '济宁', 'city_link': 'http://www.pm25.in/jining', 'aqi': {'AQI': '46', 'PM2.5/1h': '15', 'PM10/1h': '45', 'CO/1h': '0.37', 'NO2/1h': '8', 'O3/1h': '111', 'O3/8h': '88', 'SO2/1h': '6'}}
# {'name': '金坛', 'city_link': 'http://www.pm25.in/jintan', 'aqi': {'AQI': '59', 'PM2.5/1h': '18', 'PM10/1h': '66', 'CO/1h': '0.4', 'NO2/1h': '19', 'O3/1h': '120', 'O3/8h': '106', 'SO2/1h': '9'}}
# {'name': '晋中', 'city_link': 'http://www.pm25.in/jinzhong', 'aqi': {'AQI': '41', 'PM2.5/1h': '11', 'PM10/1h': '39', 'CO/1h': '0.47', 'NO2/1h': '11', 'O3/1h': '98', 'O3/8h': '80', 'SO2/1h': '9'}}
# {'name': '锦州', 'city_link': 'http://www.pm25.in/jinzhou', 'aqi': {'AQI': '41', 'PM2.5/1h': '10', 'PM10/1h': '40', 'CO/1h': '0.46', 'NO2/1h': '12', 'O3/1h': '74', 'O3/8h': '76', 'SO2/1h': '20'}}
# {'name': '九江', 'city_link': 'http://www.pm25.in/jiujiang', 'aqi': {'AQI': '63', 'PM2.5/1h': '29', 'PM10/1h': '74', 'CO/1h': '0.5', 'NO2/1h': '22', 'O3/1h': '107', 'O3/8h': '101', 'SO2/1h': '14'}}
# {'name': '酒泉', 'city_link': 'http://www.pm25.in/jiuquan', 'aqi': {'AQI': '48', 'PM2.5/1h': '16', 'PM10/1h': '44', 'CO/1h': '0.45', 'NO2/1h': '6', 'O3/1h': '112', 'O3/8h': '95', 'SO2/1h': '9'}}
# {'name': '鸡西', 'city_link': 'http://www.pm25.in/jixi', 'aqi': {'AQI': '40', 'PM2.5/1h': '28', 'PM10/1h': '30', 'CO/1h': '0.5', 'NO2/1h': '17', 'O3/1h': '72', 'O3/8h': '69', 'SO2/1h': '7'}}
# {'name': '句容', 'city_link': 'http://www.pm25.in/jurong', 'aqi': {'AQI': '60', 'PM2.5/1h': '14', 'PM10/1h': '40', 'CO/1h': '0.7', 'NO2/1h': '25', 'O3/1h': '124', 'O3/8h': '110', 'SO2/1h': '6'}}
# {'name': '开封', 'city_link': 'http://www.pm25.in/kaifeng', 'aqi': {'AQI': '50', 'PM2.5/1h': '17', 'PM10/1h': '32', 'CO/1h': '0.5', 'NO2/1h': '14', 'O3/1h': '115', 'O3/8h': '99', 'SO2/1h': '7'}}
# {'name': '喀什地区', 'city_link': 'http://www.pm25.in/kashediqu', 'aqi': {'AQI': '135', 'PM2.5/1h': '64', 'PM10/1h': '217', 'CO/1h': '0.45', 'NO2/1h': '19', 'O3/1h': '103', 'O3/8h': '72', 'SO2/1h': '5'}}
# {'name': '克拉玛依', 'city_link': 'http://www.pm25.in/kelamayi', 'aqi': {'AQI': '48', 'PM2.5/1h': '23', 'PM10/1h': '47', 'CO/1h': '0.64', 'NO2/1h': '18', 'O3/1h': '72', 'O3/8h': '69', 'SO2/1h': '3'}}
# {'name': '克州', 'city_link': 'http://www.pm25.in/kezhou', 'aqi': {'AQI': '382', 'PM2.5/1h': '45', 'PM10/1h': '484', 'CO/1h': '0.2', 'NO2/1h': '0', 'O3/1h': '77', 'O3/8h': '72', 'SO2/1h': '5'}}
# {'name': '库尔勒', 'city_link': 'http://www.pm25.in/kuerle', 'aqi': {'AQI': '120', 'PM2.5/1h': '34', 'PM10/1h': '188', 'CO/1h': '0.43', 'NO2/1h': '7', 'O3/1h': '102', 'O3/8h': '92', 'SO2/1h': '4'}}
# {'name': '昆明', 'city_link': 'http://www.pm25.in/kunming', 'aqi': {'AQI': '69', 'PM2.5/1h': '49', 'PM10/1h': '77', 'CO/1h': '1.05', 'NO2/1h': '29', 'O3/1h': '123', 'O3/8h': '97', 'SO2/1h': '11'}}
# {'name': '昆山', 'city_link': 'http://www.pm25.in/kunshan', 'aqi': {'AQI': '77', 'PM2.5/1h': '56', 'PM10/1h': '102', 'CO/1h': '0.8', 'NO2/1h': '26', 'O3/1h': '133', 'O3/8h': '102', 'SO2/1h': '12'}}
# {'name': '来宾', 'city_link': 'http://www.pm25.in/laibin', 'aqi': {'AQI': '55', 'PM2.5/1h': '38', 'PM10/1h': '56', 'CO/1h': '1.05', 'NO2/1h': '26', 'O3/1h': '71', 'O3/8h': '69', 'SO2/1h': '15'}}
# {'name': '莱芜', 'city_link': 'http://www.pm25.in/laiwu', 'aqi': {'AQI': '88', 'PM2.5/1h': '65', 'PM10/1h': '99', 'CO/1h': '0.67', 'NO2/1h': '18', 'O3/1h': '89', 'O3/8h': '77', 'SO2/1h': '10'}}
# {'name': '莱西', 'city_link': 'http://www.pm25.in/laixi', 'aqi': {'AQI': '44', 'PM2.5/1h': '6', 'PM10/1h': '32', 'CO/1h': '0.3', 'NO2/1h': '3', 'O3/1h': '92', 'O3/8h': '87', 'SO2/1h': '5'}}
# {'name': '莱州', 'city_link': 'http://www.pm25.in/laizhou', 'aqi': {'AQI': '44', 'PM2.5/1h': '1', 'PM10/1h': '6', 'CO/1h': '0.7', 'NO2/1h': '7', 'O3/1h': '90', 'O3/8h': '86', 'SO2/1h': '8'}}
# {'name': '廊坊', 'city_link': 'http://www.pm25.in/langfang', 'aqi': {'AQI': '43', 'PM2.5/1h': '12', 'PM10/1h': '26', 'CO/1h': '0.48', 'NO2/1h': '14', 'O3/1h': '89', 'O3/8h': '85', 'SO2/1h': '2'}}
# {'name': '兰州', 'city_link': 'http://www.pm25.in/lanzhou', 'aqi': {'AQI': '60', 'PM2.5/1h': '29', 'PM10/1h': '67', 'CO/1h': '0.68', 'NO2/1h': '34', 'O3/1h': '118', 'O3/8h': '101', 'SO2/1h': '9'}}
# {'name': '拉萨', 'city_link': 'http://www.pm25.in/lasa', 'aqi': {'AQI': '74', 'PM2.5/1h': '16', 'PM10/1h': '95', 'CO/1h': '0.4', 'NO2/1h': '7', 'O3/1h': '104', 'O3/8h': '99', 'SO2/1h': '3'}}
# {'name': '乐山', 'city_link': 'http://www.pm25.in/leshan', 'aqi': {'AQI': '33', 'PM2.5/1h': '22', 'PM10/1h': '32', 'CO/1h': '0.5', 'NO2/1h': '12', 'O3/1h': '98', 'O3/8h': '50', 'SO2/1h': '5'}}
# {'name': '凉山州', 'city_link': 'http://www.pm25.in/liangshanzhou', 'aqi': {'AQI': '42', 'PM2.5/1h': '8', 'PM10/1h': '18', 'CO/1h': '0.66', 'NO2/1h': '12', 'O3/1h': '90', 'O3/8h': '83', 'SO2/1h': '11'}}
# {'name': '连云港', 'city_link': 'http://www.pm25.in/lianyungang', 'aqi': {'AQI': '57', 'PM2.5/1h': '12', 'PM10/1h': '61', 'CO/1h': '0.66', 'NO2/1h': '30', 'O3/1h': '82', 'O3/8h': '83', 'SO2/1h': '11'}}
# {'name': '聊城', 'city_link': 'http://www.pm25.in/liaocheng', 'aqi': {'AQI': '61', 'PM2.5/1h': '18', 'PM10/1h': '70', 'CO/1h': '0.47', 'NO2/1h': '22', 'O3/1h': '104', 'O3/8h': '86', 'SO2/1h': '10'}}
# {'name': '辽阳', 'city_link': 'http://www.pm25.in/liaoyang', 'aqi': {'AQI': '33', 'PM2.5/1h': '16', 'PM10/1h': '32', 'CO/1h': '0.43', 'NO2/1h': '13', 'O3/1h': '82', 'O3/8h': '64', 'SO2/1h': '9'}}
# {'name': '辽源', 'city_link': 'http://www.pm25.in/liaoyuan', 'aqi': {'AQI': '42', 'PM2.5/1h': '13', 'PM10/1h': '26', 'CO/1h': '0.55', 'NO2/1h': '10', 'O3/1h': '82', 'O3/8h': '83', 'SO2/1h': '21'}}
# {'name': '丽江', 'city_link': 'http://www.pm25.in/lijiang', 'aqi': {'AQI': '50', 'PM2.5/1h': '19', 'PM10/1h': '45', 'CO/1h': '0.57', 'NO2/1h': '7', 'O3/1h': '103', 'O3/8h': '98', 'SO2/1h': '6'}}
# {'name': '临安', 'city_link': 'http://www.pm25.in/linan', 'aqi': {'AQI': '75', 'PM2.5/1h': '29', 'PM10/1h': '97', 'CO/1h': '0.65', 'NO2/1h': '22', 'O3/1h': '80', 'O3/8h': '87', 'SO2/1h': '8'}}
# {'name': '临沧', 'city_link': 'http://www.pm25.in/lincang', 'aqi': {'AQI': '94', 'PM2.5/1h': '60', 'PM10/1h': '135', 'CO/1h': '0.65', 'NO2/1h': '6', 'O3/1h': '130', 'O3/8h': '120', 'SO2/1h': '9'}}
# {'name': '临汾', 'city_link': 'http://www.pm25.in/linfen', 'aqi': {'AQI': '52', 'PM2.5/1h': '27', 'PM10/1h': '51', 'CO/1h': '0.95', 'NO2/1h': '13', 'O3/1h': '111', 'O3/8h': '84', 'SO2/1h': '21'}}
# {'name': '临夏州', 'city_link': 'http://www.pm25.in/linxiazhou', 'aqi': {'AQI': '46', 'PM2.5/1h': '13', 'PM10/1h': '22', 'CO/1h': '0.55', 'NO2/1h': '13', 'O3/1h': '119', 'O3/8h': '90', 'SO2/1h': '4'}}
# {'name': '临沂', 'city_link': 'http://www.pm25.in/linyi', 'aqi': {'AQI': '62', 'PM2.5/1h': '15', 'PM10/1h': '72', 'CO/1h': '0.35', 'NO2/1h': '21', 'O3/1h': '98', 'O3/8h': '88', 'SO2/1h': '6'}}
# {'name': '林芝', 'city_link': 'http://www.pm25.in/linzhi', 'aqi': {'AQI': '51', 'PM2.5/1h': '19', 'PM10/1h': '46', 'CO/1h': '0.45', 'NO2/1h': '9', 'O3/1h': '105', 'O3/8h': '100', 'SO2/1h': '1'}}
# {'name': '林芝地区', 'city_link': 'http://www.pm25.in/linzhidiqu', 'aqi': {'AQI': '18', 'PM2.5/1h': '4', 'PM10/1h': '16', 'CO/1h': '0.35', 'NO2/1h': '6', 'O3/1h': '51', 'O3/8h': '35', 'SO2/1h': '3'}}
# {'name': '丽水', 'city_link': 'http://www.pm25.in/lishui', 'aqi': {'AQI': '48', 'PM2.5/1h': '14', 'PM10/1h': '41', 'CO/1h': '0.47', 'NO2/1h': '13', 'O3/1h': '114', 'O3/8h': '95', 'SO2/1h': '7'}}
# {'name': '六盘水', 'city_link': 'http://www.pm25.in/liupanshui', 'aqi': {'AQI': '38', 'PM2.5/1h': '15', 'PM10/1h': '24', 'CO/1h': '0.56', 'NO2/1h': '24', 'O3/1h': '75', 'O3/8h': '74', 'SO2/1h': '18'}}
# {'name': '柳州', 'city_link': 'http://www.pm25.in/liuzhou', 'aqi': {'AQI': '48', 'PM2.5/1h': '33', 'PM10/1h': '41', 'CO/1h': '0.7', 'NO2/1h': '21', 'O3/1h': '59', 'O3/8h': '52', 'SO2/1h': '12'}}
# {'name': '溧阳', 'city_link': 'http://www.pm25.in/liyang', 'aqi': {'AQI': '66', 'PM2.5/1h': '34', 'PM10/1h': '68', 'CO/1h': '1.05', 'NO2/1h': '21', 'O3/1h': '132', 'O3/8h': '117', 'SO2/1h': '10'}}
# {'name': '陇南', 'city_link': 'http://www.pm25.in/longnan', 'aqi': {'AQI': '38', 'PM2.5/1h': '9', 'PM10/1h': '37', 'CO/1h': '0.45', 'NO2/1h': '9', 'O3/1h': '100', 'O3/8h': '73', 'SO2/1h': '6'}}
# {'name': '龙岩', 'city_link': 'http://www.pm25.in/longyan', 'aqi': {'AQI': '44', 'PM2.5/1h': '12', 'PM10/1h': '26', 'CO/1h': '0.45', 'NO2/1h': '12', 'O3/1h': '98', 'O3/8h': '86', 'SO2/1h': '5'}}
# {'name': '娄底', 'city_link': 'http://www.pm25.in/loudi', 'aqi': {'AQI': '49', 'PM2.5/1h': '27', 'PM10/1h': '48', 'CO/1h': '0.6', 'NO2/1h': '20', 'O3/1h': '91', 'O3/8h': '80', 'SO2/1h': '4'}}
# {'name': '六安', 'city_link': 'http://www.pm25.in/luan', 'aqi': {'AQI': '60', 'PM2.5/1h': '27', 'PM10/1h': '68', 'CO/1h': '0.45', 'NO2/1h': '15', 'O3/1h': '90', 'O3/8h': '75', 'SO2/1h': '10'}}
# {'name': '漯河', 'city_link': 'http://www.pm25.in/luohe', 'aqi': {'AQI': '48', 'PM2.5/1h': '4', 'PM10/1h': '31', 'CO/1h': '0.28', 'NO2/1h': '10', 'O3/1h': '108', 'O3/8h': '94', 'SO2/1h': '8'}}
# {'name': '洛阳', 'city_link': 'http://www.pm25.in/luoyang', 'aqi': {'AQI': '45', 'PM2.5/1h': '8', 'PM10/1h': '31', 'CO/1h': '0.22', 'NO2/1h': '11', 'O3/1h': '105', 'O3/8h': '89', 'SO2/1h': '8'}}
# {'name': '泸州', 'city_link': 'http://www.pm25.in/luzhou', 'aqi': {'AQI': '34', 'PM2.5/1h': '21', 'PM10/1h': '33', 'CO/1h': '0.45', 'NO2/1h': '23', 'O3/1h': '64', 'O3/8h': '56', 'SO2/1h': '5'}}
# {'name': '吕梁', 'city_link': 'http://www.pm25.in/lvliang', 'aqi': {'AQI': '36', 'PM2.5/1h': '3', 'PM10/1h': '33', 'CO/1h': '0.67', 'NO2/1h': '5', 'O3/1h': '101', 'O3/8h': '71', 'SO2/1h': '6'}}
# {'name': '马鞍山', 'city_link': 'http://www.pm25.in/maanshan', 'aqi': {'AQI': '54', 'PM2.5/1h': '13', 'PM10/1h': '56', 'CO/1h': '0.58', 'NO2/1h': '21', 'O3/1h': '109', 'O3/8h': '101', 'SO2/1h': '15'}}
# {'name': '茂名', 'city_link': 'http://www.pm25.in/maoming', 'aqi': {'AQI': '58', 'PM2.5/1h': '40', 'PM10/1h': '56', 'CO/1h': '0.8', 'NO2/1h': '17', 'O3/1h': '77', 'O3/8h': '70', 'SO2/1h': '6'}}
# {'name': '眉山', 'city_link': 'http://www.pm25.in/meishan', 'aqi': {'AQI': '56', 'PM2.5/1h': '35', 'PM10/1h': '60', 'CO/1h': '0.65', 'NO2/1h': '29', 'O3/1h': '68', 'O3/8h': '47', 'SO2/1h': '9'}}
# {'name': '梅州', 'city_link': 'http://www.pm25.in/meizhou', 'aqi': {'AQI': '39', 'PM2.5/1h': '23', 'PM10/1h': '38', 'CO/1h': '0.8', 'NO2/1h': '19', 'O3/1h': '92', 'O3/8h': '75', 'SO2/1h': '6'}}
# {'name': '绵阳', 'city_link': 'http://www.pm25.in/mianyang', 'aqi': {'AQI': '70', 'PM2.5/1h': '50', 'PM10/1h': '71', 'CO/1h': '0.5', 'NO2/1h': '40', 'O3/1h': '56', 'O3/8h': '54', 'SO2/1h': '12'}}
# {'name': '牡丹江', 'city_link': 'http://www.pm25.in/mudanjiang', 'aqi': {'AQI': '44', 'PM2.5/1h': '26', 'PM10/1h': '37', 'CO/1h': '0.46', 'NO2/1h': '18', 'O3/1h': '85', 'O3/8h': '86', 'SO2/1h': '4'}}
# {'name': '南昌', 'city_link': 'http://www.pm25.in/nanchang', 'aqi': {'AQI': '62', 'PM2.5/1h': '15', 'PM10/1h': '55', 'CO/1h': '0.53', 'NO2/1h': '15', 'O3/1h': '146', 'O3/8h': '113', 'SO2/1h': '6'}}
# {'name': '南充', 'city_link': 'http://www.pm25.in/nanchong', 'aqi': {'AQI': '59', 'PM2.5/1h': '35', 'PM10/1h': '66', 'CO/1h': '0.48', 'NO2/1h': '15', 'O3/1h': '89', 'O3/8h': '75', 'SO2/1h': '4'}}
# {'name': '南京', 'city_link': 'http://www.pm25.in/nanjing', 'aqi': {'AQI': '53', 'PM2.5/1h': '12', 'PM10/1h': '53', 'CO/1h': '0.45', 'NO2/1h': '17', 'O3/1h': '108', 'O3/8h': '96', 'SO2/1h': '9'}}
# {'name': '南宁', 'city_link': 'http://www.pm25.in/nanning', 'aqi': {'AQI': '49', 'PM2.5/1h': '25', 'PM10/1h': '48', 'CO/1h': '0.77', 'NO2/1h': '31', 'O3/1h': '48', 'O3/8h': '43', 'SO2/1h': '10'}}
# {'name': '南平', 'city_link': 'http://www.pm25.in/nanping', 'aqi': {'AQI': '56', 'PM2.5/1h': '15', 'PM10/1h': '37', 'CO/1h': '0.5', 'NO2/1h': '8', 'O3/1h': '116', 'O3/8h': '106', 'SO2/1h': '8'}}
# {'name': '南通', 'city_link': 'http://www.pm25.in/nantong', 'aqi': {'AQI': '58', 'PM2.5/1h': '20', 'PM10/1h': '64', 'CO/1h': '0.34', 'NO2/1h': '27', 'O3/1h': '105', 'O3/8h': '86', 'SO2/1h': '10'}}
# {'name': '南阳', 'city_link': 'http://www.pm25.in/nanyang', 'aqi': {'AQI': '53', 'PM2.5/1h': '19', 'PM10/1h': '54', 'CO/1h': '0.6', 'NO2/1h': '18', 'O3/1h': '116', 'O3/8h': '86', 'SO2/1h': '5'}}
# {'name': '那曲地区', 'city_link': 'http://www.pm25.in/naqudiqu', 'aqi': {'AQI': '37', 'PM2.5/1h': '16', 'PM10/1h': '27', 'CO/1h': '0.53', 'NO2/1h': '5', 'O3/1h': '82', 'O3/8h': '72', 'SO2/1h': '4'}}
# {'name': '内江', 'city_link': 'http://www.pm25.in/neijiang', 'aqi': {'AQI': '39', 'PM2.5/1h': '27', 'PM10/1h': '38', 'CO/1h': '0.73', 'NO2/1h': '28', 'O3/1h': '69', 'O3/8h': '51', 'SO2/1h': '5'}}
# {'name': '宁波', 'city_link': 'http://www.pm25.in/ningbo', 'aqi': {'AQI': '57', 'PM2.5/1h': '32', 'PM10/1h': '61', 'CO/1h': '0.63', 'NO2/1h': '29', 'O3/1h': '125', 'O3/8h': '87', 'SO2/1h': '9'}}
# {'name': '宁德', 'city_link': 'http://www.pm25.in/ningde', 'aqi': {'AQI': '43', 'PM2.5/1h': '14', 'PM10/1h': '42', 'CO/1h': '0.67', 'NO2/1h': '19', 'O3/1h': '107', 'O3/8h': '82', 'SO2/1h': '6'}}
# {'name': '怒江州', 'city_link': 'http://www.pm25.in/nujiangzhou', 'aqi': {'AQI': '85', 'PM2.5/1h': '59', 'PM10/1h': '117', 'CO/1h': '0.9', 'NO2/1h': '18', 'O3/1h': '123', 'O3/8h': '88', 'SO2/1h': '9'}}
# {'name': '盘锦', 'city_link': 'http://www.pm25.in/panjin', 'aqi': {'AQI': '44', 'PM2.5/1h': '6', 'PM10/1h': '26', 'CO/1h': '0.47', 'NO2/1h': '11', 'O3/1h': '90', 'O3/8h': '87', 'SO2/1h': '7'}}
# {'name': '攀枝花', 'city_link': 'http://www.pm25.in/panzhihua', 'aqi': {'AQI': '65', 'PM2.5/1h': '46', 'PM10/1h': '70', 'CO/1h': '0.72', 'NO2/1h': '25', 'O3/1h': '141', 'O3/8h': '113', 'SO2/1h': '27'}}
# {'name': '蓬莱', 'city_link': 'http://www.pm25.in/penglai', 'aqi': {'AQI': '50', 'PM2.5/1h': '9', 'PM10/1h': '32', 'CO/1h': '0.45', 'NO2/1h': '8', 'O3/1h': '106', 'O3/8h': '98', 'SO2/1h': '6'}}
# {'name': '平顶山', 'city_link': 'http://www.pm25.in/pingdingshan', 'aqi': {'AQI': '50', 'PM2.5/1h': '9', 'PM10/1h': '30', 'CO/1h': '0.38', 'NO2/1h': '18', 'O3/1h': '117', 'O3/8h': '99', 'SO2/1h': '12'}}
# {'name': '平度', 'city_link': 'http://www.pm25.in/pingdu', 'aqi': {'AQI': '47', 'PM2.5/1h': '4', 'PM10/1h': '34', 'CO/1h': '0.45', 'NO2/1h': '4', 'O3/1h': '96', 'O3/8h': '92', 'SO2/1h': '4'}}
# {'name': '平凉', 'city_link': 'http://www.pm25.in/pingliang', 'aqi': {'AQI': '46', 'PM2.5/1h': '8', 'PM10/1h': '35', 'CO/1h': '0.3', 'NO2/1h': '11', 'O3/1h': '113', 'O3/8h': '90', 'SO2/1h': '6'}}
# {'name': '萍乡', 'city_link': 'http://www.pm25.in/pingxiang', 'aqi': {'AQI': '53', 'PM2.5/1h': '19', 'PM10/1h': '54', 'CO/1h': '1.26', 'NO2/1h': '32', 'O3/1h': '65', 'O3/8h': '76', 'SO2/1h': '17'}}
# {'name': '普洱', 'city_link': 'http://www.pm25.in/puer', 'aqi': {'AQI': '80', 'PM2.5/1h': '55', 'PM10/1h': '69', 'CO/1h': '0.6', 'NO2/1h': '14', 'O3/1h': '158', 'O3/8h': '134', 'SO2/1h': '6'}}
# {'name': '莆田', 'city_link': 'http://www.pm25.in/putian', 'aqi': {'AQI': '51', 'PM2.5/1h': '12', 'PM10/1h': '46', 'CO/1h': '0.56', 'NO2/1h': '26', 'O3/1h': '107', 'O3/8h': '100', 'SO2/1h': '7'}}
# {'name': '濮阳', 'city_link': 'http://www.pm25.in/puyang', 'aqi': {'AQI': '49', 'PM2.5/1h': '11', 'PM10/1h': '35', 'CO/1h': '0.6', 'NO2/1h': '12', 'O3/1h': '109', 'O3/8h': '97', 'SO2/1h': '7'}}
# {'name': '黔东南州', 'city_link': 'http://www.pm25.in/qiandongnanzhou', 'aqi': {'AQI': '33', 'PM2.5/1h': '12', 'PM10/1h': '20', 'CO/1h': '0.4', 'NO2/1h': '23', 'O3/1h': '84', 'O3/8h': '65', 'SO2/1h': '25'}}
# {'name': '黔南州', 'city_link': 'http://www.pm25.in/qiannanzhou', 'aqi': {'AQI': '34', 'PM2.5/1h': '14', 'PM10/1h': '0', 'CO/1h': '0.2', 'NO2/1h': '11', 'O3/1h': '74', 'O3/8h': '66', 'SO2/1h': '62'}}
# {'name': '黔西南州', 'city_link': 'http://www.pm25.in/qianxinanzhou', 'aqi': {'AQI': '29', 'PM2.5/1h': '18', 'PM10/1h': '28', 'CO/1h': '0.3', 'NO2/1h': '16', 'O3/1h': '55', 'O3/8h': '54', 'SO2/1h': '3'}}
# {'name': '青岛', 'city_link': 'http://www.pm25.in/qingdao', 'aqi': {'AQI': '56', 'PM2.5/1h': '9', 'PM10/1h': '60', 'CO/1h': '0.48', 'NO2/1h': '13', 'O3/1h': '80', 'O3/8h': '78', 'SO2/1h': '5'}}
# {'name': '庆阳', 'city_link': 'http://www.pm25.in/qingyang', 'aqi': {'AQI': '45', 'PM2.5/1h': '17', 'PM10/1h': '39', 'CO/1h': '0.33', 'NO2/1h': '9', 'O3/1h': '104', 'O3/8h': '89', 'SO2/1h': '6'}}
# {'name': '清远', 'city_link': 'http://www.pm25.in/qingyuan', 'aqi': {'AQI': '41', 'PM2.5/1h': '22', 'PM10/1h': '35', 'CO/1h': '0.57', 'NO2/1h': '20', 'O3/1h': '83', 'O3/8h': '80', 'SO2/1h': '8'}}
# {'name': '秦皇岛', 'city_link': 'http://www.pm25.in/qinhuangdao', 'aqi': {'AQI': '43', 'PM2.5/1h': '12', 'PM10/1h': '36', 'CO/1h': '0.34', 'NO2/1h': '15', 'O3/1h': '84', 'O3/8h': '85', 'SO2/1h': '10'}}
# {'name': '钦州', 'city_link': 'http://www.pm25.in/qinzhou', 'aqi': {'AQI': '46', 'PM2.5/1h': '31', 'PM10/1h': '45', 'CO/1h': '0.8', 'NO2/1h': '20', 'O3/1h': '59', 'O3/8h': '59', 'SO2/1h': '9'}}
# {'name': '齐齐哈尔', 'city_link': 'http://www.pm25.in/qiqihaer', 'aqi': {'AQI': '38', 'PM2.5/1h': '10', 'PM10/1h': '20', 'CO/1h': '0.43', 'NO2/1h': '10', 'O3/1h': '73', 'O3/8h': '75', 'SO2/1h': '12'}}
# {'name': '七台河', 'city_link': 'http://www.pm25.in/qitaihe', 'aqi': {'AQI': '50', 'PM2.5/1h': '29', 'PM10/1h': '49', 'CO/1h': '0.6', 'NO2/1h': '20', 'O3/1h': '87', 'O3/8h': '83', 'SO2/1h': '5'}}
# {'name': '泉州', 'city_link': 'http://www.pm25.in/quanzhou', 'aqi': {'AQI': '52', 'PM2.5/1h': '13', 'PM10/1h': '51', 'CO/1h': '0.4', 'NO2/1h': '25', 'O3/1h': '112', 'O3/8h': '92', 'SO2/1h': '10'}}
# {'name': '曲靖', 'city_link': 'http://www.pm25.in/qujing', 'aqi': {'AQI': '57', 'PM2.5/1h': '34', 'PM10/1h': '61', 'CO/1h': '1.25', 'NO2/1h': '37', 'O3/1h': '23', 'O3/8h': '17', 'SO2/1h': '11'}}
# {'name': '衢州', 'city_link': 'http://www.pm25.in/quzhou', 'aqi': {'AQI': '37', 'PM2.5/1h': '13', 'PM10/1h': '31', 'CO/1h': '0.4', 'NO2/1h': '16', 'O3/1h': '95', 'O3/8h': '73', 'SO2/1h': '6'}}
# {'name': '日喀则', 'city_link': 'http://www.pm25.in/rikaze', 'aqi': {'AQI': '52', 'PM2.5/1h': '7', 'PM10/1h': '22', 'CO/1h': '0.45', 'NO2/1h': '7', 'O3/1h': '104', 'O3/8h': '101', 'SO2/1h': '8'}}
# {'name': '日喀则地区', 'city_link': 'http://www.pm25.in/rikazediqu', 'aqi': {'AQI': '29', 'PM2.5/1h': '6', 'PM10/1h': '27', 'CO/1h': '0.35', 'NO2/1h': '2', 'O3/1h': '68', 'O3/8h': '56', 'SO2/1h': '5'}}
# {'name': '日照', 'city_link': 'http://www.pm25.in/rizhao', 'aqi': {'AQI': '77', 'PM2.5/1h': '15', 'PM10/1h': '102', 'CO/1h': '0.17', 'NO2/1h': '6', 'O3/1h': '90', 'O3/8h': '81', 'SO2/1h': '4'}}
# {'name': '荣成', 'city_link': 'http://www.pm25.in/rongcheng', 'aqi': {'AQI': '58', 'PM2.5/1h': '9', 'PM10/1h': '64', 'CO/1h': '0.65', 'NO2/1h': '15', 'O3/1h': '55', 'O3/8h': '63', 'SO2/1h': '5'}}
# {'name': '乳山', 'city_link': 'http://www.pm25.in/rushan', 'aqi': {'AQI': '51', 'PM2.5/1h': '4', 'PM10/1h': '50', 'CO/1h': '0.5', 'NO2/1h': '10', 'O3/1h': '96', 'O3/8h': '90', 'SO2/1h': '4'}}
# {'name': '三门峡', 'city_link': 'http://www.pm25.in/sanmenxia', 'aqi': {'AQI': '36', 'PM2.5/1h': '13', 'PM10/1h': '26', 'CO/1h': '0.28', 'NO2/1h': '12', 'O3/1h': '109', 'O3/8h': '71', 'SO2/1h': '4'}}
# {'name': '三明', 'city_link': 'http://www.pm25.in/sanming', 'aqi': {'AQI': '52', 'PM2.5/1h': '15', 'PM10/1h': '46', 'CO/1h': '0.38', 'NO2/1h': '10', 'O3/1h': '116', 'O3/8h': '101', 'SO2/1h': '5'}}
# {'name': '三沙', 'city_link': 'http://www.pm25.in/sansha', 'aqi': {'AQI': '30', 'PM2.5/1h': '7', 'PM10/1h': '20', 'CO/1h': '0.3', 'NO2/1h': '30', 'O3/1h': '51', 'O3/8h': '58', 'SO2/1h': '6'}}
# {'name': '三亚', 'city_link': 'http://www.pm25.in/sanya', 'aqi': {'AQI': '53', 'PM2.5/1h': '23', 'PM10/1h': '39', 'CO/1h': '0.75', 'NO2/1h': '8', 'O3/1h': '106', 'O3/8h': '102', 'SO2/1h': '2'}}
# {'name': '上海', 'city_link': 'http://www.pm25.in/shanghai', 'aqi': {'AQI': '80', 'PM2.5/1h': '58', 'PM10/1h': '85', 'CO/1h': '0.8', 'NO2/1h': '41', 'O3/1h': '123', 'O3/8h': '94', 'SO2/1h': '12'}}
# {'name': '商洛', 'city_link': 'http://www.pm25.in/shangluo', 'aqi': {'AQI': '42', 'PM2.5/1h': '10', 'PM10/1h': '34', 'CO/1h': '0.4', 'NO2/1h': '9', 'O3/1h': '114', 'O3/8h': '83', 'SO2/1h': '15'}}
# {'name': '商丘', 'city_link': 'http://www.pm25.in/shangqiu', 'aqi': {'AQI': '192', 'PM2.5/1h': '144', 'PM10/1h': '163', 'CO/1h': '1.11', 'NO2/1h': '34', 'O3/1h': '60', 'O3/8h': '54', 'SO2/1h': '8'}}
# {'name': '上饶', 'city_link': 'http://www.pm25.in/shangrao', 'aqi': {'AQI': '50', 'PM2.5/1h': '28', 'PM10/1h': '49', 'CO/1h': '0.4', 'NO2/1h': '10', 'O3/1h': '131', 'O3/8h': '88', 'SO2/1h': '5'}}
# {'name': '山南', 'city_link': 'http://www.pm25.in/shannan', 'aqi': {'AQI': '55', 'PM2.5/1h': '7', 'PM10/1h': '18', 'CO/1h': '0.5', 'NO2/1h': '5', 'O3/1h': '108', 'O3/8h': '104', 'SO2/1h': '3'}}
# {'name': '山南地区', 'city_link': 'http://www.pm25.in/shannandiqu', 'aqi': {'AQI': '40', 'PM2.5/1h': '5', 'PM10/1h': '21', 'CO/1h': '0.45', 'NO2/1h': '6', 'O3/1h': '65', 'O3/8h': '79', 'SO2/1h': '4'}}
# {'name': '汕头', 'city_link': 'http://www.pm25.in/shantou', 'aqi': {'AQI': '39', 'PM2.5/1h': '25', 'PM10/1h': '38', 'CO/1h': '0.78', 'NO2/1h': '25', 'O3/1h': '85', 'O3/8h': '73', 'SO2/1h': '8'}}
# ...
# {'name': '芜湖', 'city_link': 'http://www.pm25.in/wuhu', 'aqi': {'AQI': '56', 'PM2.5/1h': '22', 'PM10/1h': '59', 'CO/1h': '0.47', 'NO2/1h': '27', 'O3/1h': '118', 'O3/8h': '103', 'SO2/1h': '7'}}
# {'name': '吴江', 'city_link': 'http://www.pm25.in/wujiang', 'aqi': {'AQI': '85', 'PM2.5/1h': '46', 'PM10/1h': '118', 'CO/1h': '0.83', 'NO2/1h': '37', 'O3/1h': '137', 'O3/8h': '114', 'SO2/1h': '16'}}
# {'name': '五家渠', 'city_link': 'http://www.pm25.in/wujiaqu', 'aqi': {'AQI': '163', 'PM2.5/1h': '123', 'PM10/1h': '156', 'CO/1h': '2.0', 'NO2/1h': '17', 'O3/1h': '36', 'O3/8h': '32', 'SO2/1h': '16'}}
# {'name': '乌兰察布', 'city_link': 'http://www.pm25.in/wulanchabu', 'aqi': {'AQI': '45', 'PM2.5/1h': '10', 'PM10/1h': '28', 'CO/1h': '0.2', 'NO2/1h': '5', 'O3/1h': '90', 'O3/8h': '89', 'SO2/1h': '14'}}
# {'name': '乌鲁木齐', 'city_link': 'http://www.pm25.in/wulumuqi', 'aqi': {'AQI': '138', 'PM2.5/1h': '105', 'PM10/1h': '123', 'CO/1h': '1.67', 'NO2/1h': '27', 'O3/1h': '42', 'O3/8h': '38', 'SO2/1h': '6'}}
# {'name': '武威', 'city_link': 'http://www.pm25.in/wuwei', 'aqi': {'AQI': '54', 'PM2.5/1h': '22', 'PM10/1h': '55', 'CO/1h': '0.55', 'NO2/1h': '11', 'O3/1h': '113', 'O3/8h': '87', 'SO2/1h': '4'}}
# {'name': '无锡', 'city_link': 'http://www.pm25.in/wuxi', 'aqi': {'AQI': '71', 'PM2.5/1h': '23', 'PM10/1h': '89', 'CO/1h': '0.48', 'NO2/1h': '27', 'O3/1h': '116', 'O3/8h': '101', 'SO2/1h': '9'}}
# {'name': '吴忠', 'city_link': 'http://www.pm25.in/wuzhong', 'aqi': {'AQI': '45', 'PM2.5/1h': '17', 'PM10/1h': '36', 'CO/1h': '0.27', 'NO2/1h': '8', 'O3/1h': '116', 'O3/8h': '88', 'SO2/1h': '8'}}
# {'name': '梧州', 'city_link': 'http://www.pm25.in/wuzhou', 'aqi': {'AQI': '44', 'PM2.5/1h': '29', 'PM10/1h': '43', 'CO/1h': '0.93', 'NO2/1h': '15', 'O3/1h': '60', 'O3/8h': '56', 'SO2/1h': '10'}}
# {'name': '厦门', 'city_link': 'http://www.pm25.in/xiamen', 'aqi': {'AQI': '45', 'PM2.5/1h': '18', 'PM10/1h': '34', 'CO/1h': '0.43', 'NO2/1h': '16', 'O3/1h': '118', 'O3/8h': '89', 'SO2/1h': '6'}}
# {'name': '西安', 'city_link': 'http://www.pm25.in/xian', 'aqi': {'AQI': '45', 'PM2.5/1h': '17', 'PM10/1h': '44', 'CO/1h': '0.36', 'NO2/1h': '25', 'O3/1h': '96', 'O3/8h': '65', 'SO2/1h': '7'}}
# {'name': '湘潭', 'city_link': 'http://www.pm25.in/xiangtan', 'aqi': {'AQI': '59', 'PM2.5/1h': '41', 'PM10/1h': '61', 'CO/1h': '0.83', 'NO2/1h': '30', 'O3/1h': '82', 'O3/8h': '68', 'SO2/1h': '12'}}
# {'name': '湘西州', 'city_link': 'http://www.pm25.in/xiangxizhou', 'aqi': {'AQI': '51', 'PM2.5/1h': '26', 'PM10/1h': '50', 'CO/1h': '0.57', 'NO2/1h': '12', 'O3/1h': '88', 'O3/8h': '35', 'SO2/1h': '11'}}
# {'name': '襄阳', 'city_link': 'http://www.pm25.in/xiangyang', 'aqi': {'AQI': '56', 'PM2.5/1h': '19', 'PM10/1h': '60', 'CO/1h': '0.35', 'NO2/1h': '19', 'O3/1h': '116', 'O3/8h': '83', 'SO2/1h': '9'}}
# {'name': '咸宁', 'city_link': 'http://www.pm25.in/xianning', 'aqi': {'AQI': '71', 'PM2.5/1h': '12', 'PM10/1h': '20', 'CO/1h': '0.25', 'NO2/1h': '12', 'O3/1h': '138', 'O3/8h': '123', 'SO2/1h': '6'}}
# {'name': '咸阳', 'city_link': 'http://www.pm25.in/xianyang', 'aqi': {'AQI': '52', 'PM2.5/1h': '21', 'PM10/1h': '52', 'CO/1h': '0.68', 'NO2/1h': '20', 'O3/1h': '96', 'O3/8h': '66', 'SO2/1h': '7'}}
# {'name': '孝感', 'city_link': 'http://www.pm25.in/xiaogan', 'aqi': {'AQI': '62', 'PM2.5/1h': '14', 'PM10/1h': '39', 'CO/1h': '0.55', 'NO2/1h': '2', 'O3/1h': '144', 'O3/8h': '113', 'SO2/1h': '5'}}
# {'name': '锡林郭勒盟', 'city_link': 'http://www.pm25.in/xilinguolemeng', 'aqi': {'AQI': '37', 'PM2.5/1h': '6', 'PM10/1h': '12', 'CO/1h': '0.1', 'NO2/1h': '11', 'O3/1h': '71', 'O3/8h': '73', 'SO2/1h': '29'}}
# {'name': '兴安盟', 'city_link': 'http://www.pm25.in/xinganmeng', 'aqi': {'AQI': '43', 'PM2.5/1h': '15', 'PM10/1h': '21', 'CO/1h': '0.27', 'NO2/1h': '6', 'O3/1h': '82', 'O3/8h': '84', 'SO2/1h': '6'}}
# {'name': '邢台', 'city_link': 'http://www.pm25.in/xingtai', 'aqi': {'AQI': '53', 'PM2.5/1h': '12', 'PM10/1h': '53', 'CO/1h': '0.48', 'NO2/1h': '12', 'O3/1h': '100', 'O3/8h': '91', 'SO2/1h': '9'}}
# {'name': '西宁', 'city_link': 'http://www.pm25.in/xining', 'aqi': {'AQI': '52', 'PM2.5/1h': '30', 'PM10/1h': '51', 'CO/1h': '0.97', 'NO2/1h': '31', 'O3/1h': '107', 'O3/8h': '89', 'SO2/1h': '14'}}
# {'name': '新乡', 'city_link': 'http://www.pm25.in/xinxiang', 'aqi': {'AQI': '46', 'PM2.5/1h': '13', 'PM10/1h': '45', 'CO/1h': '0.6', 'NO2/1h': '20', 'O3/1h': '104', 'O3/8h': '83', 'SO2/1h': '14'}}
# {'name': '信阳', 'city_link': 'http://www.pm25.in/xinyang', 'aqi': {'AQI': '51', 'PM2.5/1h': '15', 'PM10/1h': '39', 'CO/1h': '0.38', 'NO2/1h': '8', 'O3/1h': '119', 'O3/8h': '100', 'SO2/1h': '8'}}
# {'name': '新余', 'city_link': 'http://www.pm25.in/xinyu', 'aqi': {'AQI': '55', 'PM2.5/1h': '30', 'PM10/1h': '57', 'CO/1h': '0.52', 'NO2/1h': '18', 'O3/1h': '118', 'O3/8h': '85', 'SO2/1h': '19'}}
# {'name': '忻州', 'city_link': 'http://www.pm25.in/xinzhou', 'aqi': {'AQI': '47', 'PM2.5/1h': '2', 'PM10/1h': '16', 'CO/1h': '0.23', 'NO2/1h': '11', 'O3/1h': '99', 'O3/8h': '92', 'SO2/1h': '3'}}
# {'name': '西双版纳州', 'city_link': 'http://www.pm25.in/xishuangbannazhou', 'aqi': {'AQI': '96', 'PM2.5/1h': '71', 'PM10/1h': '136', 'CO/1h': '0.75', 'NO2/1h': '17', 'O3/1h': '180', 'O3/8h': '118', 'SO2/1h': '9'}}
# {'name': '宣城', 'city_link': 'http://www.pm25.in/xuancheng', 'aqi': {'AQI': '53', 'PM2.5/1h': '26', 'PM10/1h': '54', 'CO/1h': '0.37', 'NO2/1h': '16', 'O3/1h': '120', 'O3/8h': '101', 'SO2/1h': '8'}}
# {'name': '许昌', 'city_link': 'http://www.pm25.in/xuchang', 'aqi': {'AQI': '47', 'PM2.5/1h': '9', 'PM10/1h': '37', 'CO/1h': '0.53', 'NO2/1h': '12', 'O3/1h': '109', 'O3/8h': '92', 'SO2/1h': '8'}}
# {'name': '徐州', 'city_link': 'http://www.pm25.in/xuzhou', 'aqi': {'AQI': '59', 'PM2.5/1h': '22', 'PM10/1h': '66', 'CO/1h': '0.3', 'NO2/1h': '13', 'O3/1h': '104', 'O3/8h': '89', 'SO2/1h': '6'}}
# {'name': '雅安', 'city_link': 'http://www.pm25.in/yaan', 'aqi': {'AQI': '66', 'PM2.5/1h': '47', 'PM10/1h': '75', 'CO/1h': '0.6', 'NO2/1h': '33', 'O3/1h': '52', 'O3/8h': '57', 'SO2/1h': '19'}}
# {'name': '延安', 'city_link': 'http://www.pm25.in/yanan', 'aqi': {'AQI': '38', 'PM2.5/1h': '7', 'PM10/1h': '25', 'CO/1h': '0.3', 'NO2/1h': '13', 'O3/1h': '99', 'O3/8h': '75', 'SO2/1h': '4'}}
# {'name': '延边州', 'city_link': 'http://www.pm25.in/yanbianzhou', 'aqi': {'AQI': '47', 'PM2.5/1h': '13', 'PM10/1h': '26', 'CO/1h': '0.37', 'NO2/1h': '6', 'O3/1h': '92', 'O3/8h': '93', 'SO2/1h': '4'}}
# {'name': '盐城', 'city_link': 'http://www.pm25.in/yancheng', 'aqi': {'AQI': '69', 'PM2.5/1h': '34', 'PM10/1h': '85', 'CO/1h': '0.66', 'NO2/1h': '26', 'O3/1h': '84', 'O3/8h': '97', 'SO2/1h': '11'}}
# {'name': '阳江', 'city_link': 'http://www.pm25.in/yangjiang', 'aqi': {'AQI': '53', 'PM2.5/1h': '32', 'PM10/1h': '53', 'CO/1h': '0.77', 'NO2/1h': '21', 'O3/1h': '81', 'O3/8h': '77', 'SO2/1h': '8'}}
# {'name': '阳泉', 'city_link': 'http://www.pm25.in/yangquan', 'aqi': {'AQI': '44', 'PM2.5/1h': '9', 'PM10/1h': '22', 'CO/1h': '0.38', 'NO2/1h': '6', 'O3/1h': '97', 'O3/8h': '86', 'SO2/1h': '3'}}
# {'name': '扬州', 'city_link': 'http://www.pm25.in/yangzhou', 'aqi': {'AQI': '62', 'PM2.5/1h': '24', 'PM10/1h': '71', 'CO/1h': '0.43', 'NO2/1h': '22', 'O3/1h': '98', 'O3/8h': '89', 'SO2/1h': '6'}}
# {'name': '烟台', 'city_link': 'http://www.pm25.in/yantai', 'aqi': {'AQI': '71', 'PM2.5/1h': '11', 'PM10/1h': '89', 'CO/1h': '0.3', 'NO2/1h': '13', 'O3/1h': '84', 'O3/8h': '82', 'SO2/1h': '6'}}
# {'name': '宜宾', 'city_link': 'http://www.pm25.in/yibin', 'aqi': {'AQI': '53', 'PM2.5/1h': '36', 'PM10/1h': '51', 'CO/1h': '0.56', 'NO2/1h': '39', 'O3/1h': '54', 'O3/8h': '45', 'SO2/1h': '22'}}
# {'name': '宜昌', 'city_link': 'http://www.pm25.in/yichang', 'aqi': {'AQI': '52', 'PM2.5/1h': '18', 'PM10/1h': '52', 'CO/1h': '0.48', 'NO2/1h': '23', 'O3/1h': '109', 'O3/8h': '66', 'SO2/1h': '9'}}
# {'name': '宜春', 'city_link': 'http://www.pm25.in/yichun', 'aqi': {'AQI': '55', 'PM2.5/1h': '30', 'PM10/1h': '57', 'CO/1h': '0.49', 'NO2/1h': '20', 'O3/1h': '107', 'O3/8h': '86', 'SO2/1h': '14'}}
# {'name': '伊春', 'city_link': 'http://www.pm25.in/yichunshi', 'aqi': {'AQI': '40', 'PM2.5/1h': '10', 'PM10/1h': '21', 'CO/1h': '0.33', 'NO2/1h': '7', 'O3/1h': '85', 'O3/8h': '79', 'SO2/1h': '5'}}
# {'name': '伊犁哈萨克', 'city_link': 'http://www.pm25.in/yilihasake', 'aqi': {'AQI': '0', 'PM2.5/1h': '0', 'PM10/1h': '0', 'CO/1h': '0.0', 'NO2/1h': '0', 'O3/1h': '0', 'O3/8h': '0', 'SO2/1h': '0'}}
# {'name': '伊犁哈萨克州', 'city_link': 'http://www.pm25.in/yilihasakezhou', 'aqi': {'AQI': '65', 'PM2.5/1h': '27', 'PM10/1h': '77', 'CO/1h': '0.5', 'NO2/1h': '12', 'O3/1h': '98', 'O3/8h': '66', 'SO2/1h': '4'}}
# {'name': '银川', 'city_link': 'http://www.pm25.in/yinchuan', 'aqi': {'AQI': '41', 'PM2.5/1h': '14', 'PM10/1h': '33', 'CO/1h': '0.54', 'NO2/1h': '21', 'O3/1h': '92', 'O3/8h': '80', 'SO2/1h': '23'}}
# {'name': '营口', 'city_link': 'http://www.pm25.in/yingkou', 'aqi': {'AQI': '43', 'PM2.5/1h': '10', 'PM10/1h': '26', 'CO/1h': '0.2', 'NO2/1h': '11', 'O3/1h': '91', 'O3/8h': '84', 'SO2/1h': '3'}}
# {'name': '鹰潭', 'city_link': 'http://www.pm25.in/yingtan', 'aqi': {'AQI': '58', 'PM2.5/1h': '14', 'PM10/1h': '41', 'CO/1h': '0.32', 'NO2/1h': '7', 'O3/1h': '147', 'O3/8h': '108', 'SO2/1h': '9'}}
# {'name': '义乌', 'city_link': 'http://www.pm25.in/yiwu', 'aqi': {'AQI': '64', 'PM2.5/1h': '41', 'PM10/1h': '75', 'CO/1h': '0.4', 'NO2/1h': '28', 'O3/1h': '112', 'O3/8h': '111', 'SO2/1h': '7'}}
# {'name': '宜兴', 'city_link': 'http://www.pm25.in/yixing', 'aqi': {'AQI': '66', 'PM2.5/1h': '30', 'PM10/1h': '59', 'CO/1h': '0.5', 'NO2/1h': '24', 'O3/1h': '123', 'O3/8h': '118', 'SO2/1h': '13'}}
# {'name': '益阳', 'city_link': 'http://www.pm25.in/yiyang', 'aqi': {'AQI': '59', 'PM2.5/1h': '36', 'PM10/1h': '54', 'CO/1h': '0.88', 'NO2/1h': '15', 'O3/1h': '136', 'O3/8h': '109', 'SO2/1h': '6'}}
# {'name': '永州', 'city_link': 'http://www.pm25.in/yongzhou', 'aqi': {'AQI': '66', 'PM2.5/1h': '47', 'PM10/1h': '71', 'CO/1h': '0.56', 'NO2/1h': '38', 'O3/1h': '72', 'O3/8h': '60', 'SO2/1h': '13'}}
# {'name': '岳阳', 'city_link': 'http://www.pm25.in/yueyang', 'aqi': {'AQI': '68', 'PM2.5/1h': '25', 'PM10/1h': '46', 'CO/1h': '0.84', 'NO2/1h': '18', 'O3/1h': '142', 'O3/8h': '120', 'SO2/1h': '6'}}
# {'name': '玉林', 'city_link': 'http://www.pm25.in/yulin', 'aqi': {'AQI': '49', 'PM2.5/1h': '34', 'PM10/1h': '40', 'CO/1h': '0.8', 'NO2/1h': '11', 'O3/1h': '78', 'O3/8h': '76', 'SO2/1h': '6'}}
# {'name': '榆林', 'city_link': 'http://www.pm25.in/yulinshi', 'aqi': {'AQI': '43', 'PM2.5/1h': '16', 'PM10/1h': '42', 'CO/1h': '0.79', 'NO2/1h': '35', 'O3/1h': '60', 'O3/8h': '49', 'SO2/1h': '19'}}
# {'name': '运城', 'city_link': 'http://www.pm25.in/yuncheng', 'aqi': {'AQI': '48', 'PM2.5/1h': '10', 'PM10/1h': '28', 'CO/1h': '0.33', 'NO2/1h': '8', 'O3/1h': '113', 'O3/8h': '94', 'SO2/1h': '2'}}
# {'name': '云浮', 'city_link': 'http://www.pm25.in/yunfu', 'aqi': {'AQI': '33', 'PM2.5/1h': '23', 'PM10/1h': '28', 'CO/1h': '0.67', 'NO2/1h': '19', 'O3/1h': '81', 'O3/8h': '61', 'SO2/1h': '7'}}
# {'name': '玉树州', 'city_link': 'http://www.pm25.in/yushuzhou', 'aqi': {'AQI': '39', 'PM2.5/1h': '8', 'PM10/1h': '21', 'CO/1h': '0.4', 'NO2/1h': '3', 'O3/1h': '89', 'O3/8h': '76', 'SO2/1h': '7'}}
# {'name': '玉溪', 'city_link': 'http://www.pm25.in/yuxi', 'aqi': {'AQI': '62', 'PM2.5/1h': '36', 'PM10/1h': '72', 'CO/1h': '0.67', 'NO2/1h': '11', 'O3/1h': '135', 'O3/8h': '112', 'SO2/1h': '8'}}
# {'name': '枣庄', 'city_link': 'http://www.pm25.in/zaozhuang', 'aqi': {'AQI': '62', 'PM2.5/1h': '13', 'PM10/1h': '72', 'CO/1h': '0.3', 'NO2/1h': '20', 'O3/1h': '110', 'O3/8h': '92', 'SO2/1h': '9'}}
# {'name': '张家港', 'city_link': 'http://www.pm25.in/zhangjiagang', 'aqi': {'AQI': '70', 'PM2.5/1h': '19', 'PM10/1h': '87', 'CO/1h': '0.25', 'NO2/1h': '26', 'O3/1h': '112', 'O3/8h': '94', 'SO2/1h': '5'}}
# {'name': '张家界', 'city_link': 'http://www.pm25.in/zhangjiajie', 'aqi': {'AQI': '38', 'PM2.5/1h': '9', 'PM10/1h': '28', 'CO/1h': '0.55', 'NO2/1h': '9', 'O3/1h': '105', 'O3/8h': '75', 'SO2/1h': '4'}}
# {'name': '张家口', 'city_link': 'http://www.pm25.in/zhangjiakou', 'aqi': {'AQI': '46', 'PM2.5/1h': '6', 'PM10/1h': '29', 'CO/1h': '0.6', 'NO2/1h': '5', 'O3/1h': '94', 'O3/8h': '91', 'SO2/1h': '6'}}
# {'name': '章丘', 'city_link': 'http://www.pm25.in/zhangqiu', 'aqi': {'AQI': '60', 'PM2.5/1h': '15', 'PM10/1h': '68', 'CO/1h': '0.45', 'NO2/1h': '16', 'O3/1h': '92', 'O3/8h': '84', 'SO2/1h': '11'}}
# {'name': '张掖', 'city_link': 'http://www.pm25.in/zhangye', 'aqi': {'AQI': '49', 'PM2.5/1h': '20', 'PM10/1h': '39', 'CO/1h': '0.2', 'NO2/1h': '7', 'O3/1h': '118', 'O3/8h': '97', 'SO2/1h': '9'}}
# {'name': '漳州', 'city_link': 'http://www.pm25.in/zhangzhou', 'aqi': {'AQI': '54', 'PM2.5/1h': '37', 'PM10/1h': '45', 'CO/1h': '0.77', 'NO2/1h': '35', 'O3/1h': '84', 'O3/8h': '68', 'SO2/1h': '5'}}
# {'name': '湛江', 'city_link': 'http://www.pm25.in/zhanjiang', 'aqi': {'AQI': '56', 'PM2.5/1h': '39', 'PM10/1h': '52', 'CO/1h': '0.82', 'NO2/1h': '16', 'O3/1h': '85', 'O3/8h': '69', 'SO2/1h': '7'}}
# {'name': '肇庆', 'city_link': 'http://www.pm25.in/zhaoqing', 'aqi': {'AQI': '43', 'PM2.5/1h': '27', 'PM10/1h': '42', 'CO/1h': '0.6', 'NO2/1h': '24', 'O3/1h': '91', 'O3/8h': '63', 'SO2/1h': '8'}}
# {'name': '昭通', 'city_link': 'http://www.pm25.in/zhaotong', 'aqi': {'AQI': '57', 'PM2.5/1h': '22', 'PM10/1h': '61', 'CO/1h': '0.65', 'NO2/1h': '22', 'O3/1h': '85', 'O3/8h': '81', 'SO2/1h': '8'}}
# {'name': '招远', 'city_link': 'http://www.pm25.in/zhaoyuan', 'aqi': {'AQI': '52', 'PM2.5/1h': '9', 'PM10/1h': '31', 'CO/1h': '0.4', 'NO2/1h': '15', 'O3/1h': '107', 'O3/8h': '101', 'SO2/1h': '8'}}
# {'name': '郑州', 'city_link': 'http://www.pm25.in/zhengzhou', 'aqi': {'AQI': '45', 'PM2.5/1h': '12', 'PM10/1h': '33', 'CO/1h': '0.35', 'NO2/1h': '15', 'O3/1h': '101', 'O3/8h': '88', 'SO2/1h': '6'}}
# {'name': '镇江', 'city_link': 'http://www.pm25.in/zhenjiang', 'aqi': {'AQI': '54', 'PM2.5/1h': '16', 'PM10/1h': '55', 'CO/1h': '0.3', 'NO2/1h': '28', 'O3/1h': '104', 'O3/8h': '88', 'SO2/1h': '5'}}
# {'name': '中山', 'city_link': 'http://www.pm25.in/zhongshan', 'aqi': {'AQI': '55', 'PM2.5/1h': '38', 'PM10/1h': '57', 'CO/1h': '0.65', 'NO2/1h': '49', 'O3/1h': '67', 'O3/8h': '60', 'SO2/1h': '15'}}
# {'name': '中卫', 'city_link': 'http://www.pm25.in/zhongwei', 'aqi': {'AQI': '73', 'PM2.5/1h': '15', 'PM10/1h': '94', 'CO/1h': '0.5', 'NO2/1h': '12', 'O3/1h': '112', 'O3/8h': '75', 'SO2/1h': '6'}}
# {'name': '周口', 'city_link': 'http://www.pm25.in/zhoukou', 'aqi': {'AQI': '52', 'PM2.5/1h': '9', 'PM10/1h': '43', 'CO/1h': '0.45', 'NO2/1h': '12', 'O3/1h': '120', 'O3/8h': '101', 'SO2/1h': '9'}}
# {'name': '舟山', 'city_link': 'http://www.pm25.in/zhoushan', 'aqi': {'AQI': '53', 'PM2.5/1h': '31', 'PM10/1h': '54', 'CO/1h': '0.5', 'NO2/1h': '27', 'O3/1h': '106', 'O3/8h': '71', 'SO2/1h': '6'}}
# {'name': '珠海', 'city_link': 'http://www.pm25.in/zhuhai', 'aqi': {'AQI': '63', 'PM2.5/1h': '44', 'PM10/1h': '67', 'CO/1h': '0.75', 'NO2/1h': '47', 'O3/1h': '64', 'O3/8h': '60', 'SO2/1h': '5'}}
# {'name': '诸暨', 'city_link': 'http://www.pm25.in/zhuji', 'aqi': {'AQI': '67', 'PM2.5/1h': '36', 'PM10/1h': '82', 'CO/1h': '0.5', 'NO2/1h': '40', 'O3/1h': '45', 'O3/8h': '85', 'SO2/1h': '8'}}
# {'name': '驻马店', 'city_link': 'http://www.pm25.in/zhumadian', 'aqi': {'AQI': '44', 'PM2.5/1h': '14', 'PM10/1h': '37', 'CO/1h': '0.15', 'NO2/1h': '3', 'O3/1h': '114', 'O3/8h': '87', 'SO2/1h': '7'}}
# {'name': '株洲', 'city_link': 'http://www.pm25.in/zhuzhou', 'aqi': {'AQI': '71', 'PM2.5/1h': '47', 'PM10/1h': '89', 'CO/1h': '0.48', 'NO2/1h': '59', 'O3/1h': '69', 'O3/8h': '61', 'SO2/1h': '8'}}
# {'name': '淄博', 'city_link': 'http://www.pm25.in/zibo', 'aqi': {'AQI': '47', 'PM2.5/1h': '13', 'PM10/1h': '46', 'CO/1h': '0.36', 'NO2/1h': '18', 'O3/1h': '96', 'O3/8h': '91', 'SO2/1h': '13'}}
# {'name': '自贡', 'city_link': 'http://www.pm25.in/zigong', 'aqi': {'AQI': '58', 'PM2.5/1h': '40', 'PM10/1h': '51', 'CO/1h': '0.45', 'NO2/1h': '13', 'O3/1h': '61', 'O3/8h': '51', 'SO2/1h': '5'}}
# {'name': '资阳', 'city_link': 'http://www.pm25.in/ziyang', 'aqi': {'AQI': '53', 'PM2.5/1h': '36', 'PM10/1h': '48', 'CO/1h': '0.46', 'NO2/1h': '20', 'O3/1h': '70', 'O3/8h': '52', 'SO2/1h': '5'}}
# {'name': '遵义', 'city_link': 'http://www.pm25.in/zunyi', 'aqi': {'AQI': '24', 'PM2.5/1h': '14', 'PM10/1h': '23', 'CO/1h': '0.5', 'NO2/1h': '27', 'O3/1h': '51', 'O3/8h': '44', 'SO2/1h': '13'}}
